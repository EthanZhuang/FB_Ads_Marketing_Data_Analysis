# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights
from facebook_business.api import FacebookAdsApi
from datetime import datetime, timedelta
import csv
import time

# Initialize the access_token
access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# Insight API中的fields資料(控制需要的欄位資料)
fields = [
    'spend',
    'campaign_name',
    'adset_name',
    'campaign_id',
    'actions',
    'objective',
    'action_values',  
    'conversions',
    'conversion_values',
]


time_period = timedelta(weeks = 4)
start_time = datetime.now() - timedelta(days = 7) 
end_time = start_time - time_period
# 用於主程式的 time_range
# start_time.strftime('%Y-%m-%d')

# Insight API中的fields資料(控制日期條件、資料的層級)
params = {
    'time_range': {
                'since': end_time.strftime('%Y-%m-%d'),\
                'until': start_time.strftime('%Y-%m-%d') 
    }, 
    
    'level': {'campaign'},
    'time_increment': '1',
    
    # Default 歸因(目前確認和廣告面板上面的相同 7天點擊 + 7天瀏覽)
    # 'use_account_attribution_setting': 'True',

    # 自己設定的歸因(和廣告預設值有落差)
    'action_attribution_windows': {'7d_click'},
}

acc_insights = AdAccount(ad_account_id).get_insights(
    fields = fields,
    params = params,
)

# 寫入資料庫-----------------------------------------------------
# 日報
# outfn = '{%Y-%m-%d}.database.csv'.format(datetime.today())
run_time = time.time()

# 建立CSV資料，並將Business SDK獲得的資料儲存
outfn = '{}_fb.csv'.format('FB_Ads_Marketing_Data')
title_row = ['Campaign_name', 'Objective', 'Amount_spent(NTD)', \
             'Amount_install', \
             'Amount_purchase' , 'Purchase_Conversion_Value',\
             'Amount_subscribe', 'Subscribe_Conversion_Value', \
             'Reporting_date']

with open(outfn, 'w', newline = '') as csvout:
    csvWriter = csv.writer(csvout)
    csvWriter.writerow(title_row)
    
    for acc_insight in acc_insights:     
        Campaign_name = ''
        Amount_spent = ''
        Objective = ''
        Amount_subscribe = '' 
        Subscribe_Conversion_Value = ''
        Amount_install = '' 
        Amount_purchase = ''    
        Purchase_Conversion_Value = ''
        Reporting_date = ''

        # insights/campaign_name得到 "產品包名稱"
        if 'campaign_name' in acc_insight:
            Campaign_name = acc_insight['campaign_name']
        
        # insights/spend得到 "總支出成本"
        if 'spend' in acc_insight:    
            Amount_spent = acc_insight['spend']
        
        # insights/objective得到 "廣告目標"
        if 'objective' in acc_insight:
            Objective = acc_insight['objective']
            
        # insights/date_stop得到 "報表終止日期"
        if 'date_stop' in acc_insight:
            Reporting_date = acc_insight['date_stop']

        # insights/actions得到 "軟體下載數/課程購買數"
        if 'actions' in acc_insight:
            for action in acc_insight['actions']:
                if action['action_type'] == 'mobile_app_install': 
                    Amount_install = action['value']
                if action['action_type'] == 'purchase':
                    Amount_purchase = action['value']

        # insights/action_values得到 "購買轉換價值"
        if 'action_values' in acc_insight:
            for ac_values in acc_insight['action_values']:
                if ac_values['action_type'] == 'omni_purchase':
                    Purchase_Conversion_Value = ac_values['value']
        
        # insights/conversions得到 "訂閱數"
        if 'conversions' in acc_insight:
            for cv in acc_insight['conversions']:
                if cv['action_type'] == 'subscribe_total':
                    try:
                        Amount_subscribe = cv['7d_click']
                    except:
                        Amount_subscribe = cv['value']

        # insights/conversion_values得到 "訂閱轉換價值"             
        if 'conversion_values' in acc_insight:
            for cv_values in acc_insight['conversion_values']:
                if cv_values['action_type'] == 'subscribe_total':
                    try:
                        Subscribe_Conversion_Value = cv_values['7d_click']
                    except:
                        Subscribe_Conversion_Value = cv_values['value']

        csvWriter.writerow([
            Campaign_name,
            Objective,
            Amount_spent,
            Amount_install, 
            Amount_purchase,
            Purchase_Conversion_Value,
            Amount_subscribe,
            Subscribe_Conversion_Value,
            Reporting_date,
        ])
        
        # 列印出資料數值，給予比對             
        print(acc_insight['campaign_name'] + '\n', acc_insight)

# flag確立program完整結束
print('finish_1')       
print('--- %s seconds ---' % (time.time() - run_time))
# Out:
# 期貨電子盤_下載_IOS(舊)
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "4",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "6"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "link_click",
#             "value": "6"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "mobile_app_install",
#             "value": "2"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "omni_activate_app",
#             "value": "6"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "page_engagement",
#             "value": "6"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "post_engagement",
#             "value": "6"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_app_install",
#             "value": "2"
#         }
#     ],
#     "campaign_id": "6098903020807",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_IOS(\u820a)",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "55"
# }
# 權證小哥_講座_轉換次數(購買)
#  <AdsInsights> {
#     "action_values": [
#         {
#             "7d_click": "25233",
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "55767"
#         },
#         {
#             "7d_click": "3577",
#             "action_type": "offsite_conversion.custom.1234714570219704",
#             "value": "7178"
#         },
#         {
#             "action_type": "offsite_conversion.custom.274646037305046",
#             "value": "7777"
#         },
#         {
#             "action_type": "offsite_conversion.custom.419162548761345",
#             "value": "7777"
#         },
#         {
#             "7d_click": "19740",
#             "action_type": "offsite_conversion.custom.425412618424162",
#             "value": "31588"
#         },
#         {
#             "action_type": "offsite_conversion.custom.492859837943669",
#             "value": "16398"
#         },
#         {
#             "7d_click": "3771",
#             "action_type": "offsite_conversion.custom.797743954347205",
#             "value": "3771"
#         },
#         {
#             "7d_click": "25233",
#             "action_type": "omni_purchase",
#             "value": "55767"
#         }
#     ],
#     "actions": [
#         {
#             "7d_click": "152",
#             "action_type": "landing_page_view",
#             "value": "152"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "onsite_conversion.post_save",
#             "value": "2"
#         },
#         {
#             "7d_click": "175",
#             "action_type": "link_click",
#             "value": "175"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "60"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "15"
#         },
#         {
#             "7d_click": "67",
#             "action_type": "post_reaction",
#             "value": "67"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.custom.1234714570219704",
#             "value": "2"
#         },
#         {
#             "action_type": "offsite_conversion.custom.274646037305046",
#             "value": "1"
#         },
#         {
#             "7d_click": "46",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "94"
#         },
#         {
#             "action_type": "offsite_conversion.custom.419162548761345",
#             "value": "1"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "offsite_conversion.custom.425412618424162",
#             "value": "8"
#         },
#         {
#             "action_type": "offsite_conversion.custom.492859837943669",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.custom.797743954347205",
#             "value": "1"
#         },
#         {
#             "7d_click": "244",
#             "action_type": "page_engagement",
#             "value": "244"
#         },
#         {
#             "7d_click": "244",
#             "action_type": "post_engagement",
#             "value": "244"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "omni_add_to_cart",
#             "value": "60"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "omni_purchase",
#             "value": "15"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "add_to_cart",
#             "value": "60"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "purchase",
#             "value": "15"
#         }
#     ],
#     "campaign_id": "6142030448607",
#     "campaign_name": "\u6b0a\u8b49\u5c0f\u54e5_\u8b1b\u5ea7_\u8f49\u63db\u6b21\u6578(\u8cfc\u8cb7)",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "CONVERSIONS",
#     "spend": "2462"
# }
# 20200923_籌碼K線_最後衝刺_iOS
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "317",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "1005"
#         },
#         {
#             "7d_click": "71",
#             "action_type": "link_click",
#             "value": "71"
#         },
#         {
#             "7d_click": "16",
#             "action_type": "mobile_app_install",
#             "value": "24"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "post_reaction",
#             "value": "2"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "317",
#             "action_type": "omni_activate_app",
#             "value": "1005"
#         },
#         {
#             "7d_click": "73",
#             "action_type": "page_engagement",
#             "value": "73"
#         },
#         {
#             "7d_click": "73",
#             "action_type": "post_engagement",
#             "value": "73"
#         },
#         {
#             "7d_click": "16",
#             "action_type": "omni_app_install",
#             "value": "24"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "view_content",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6188160278407",
#     "campaign_name": "20200923_\u7c4c\u78bcK\u7dda_\u6700\u5f8c\u885d\u523a_iOS",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "500"
# }
# 股市爆料同學會_測試專用_20200606(下載)
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2",
#             "action_type": "landing_page_view",
#             "value": "2"
#         },
#         {
#             "7d_click": "2253",
#             "action_type": "app_custom_event.other",
#             "value": "6580"
#         },
#         {
#             "7d_click": "561",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "1971"
#         },
#         {
#             "7d_click": "94",
#             "action_type": "link_click",
#             "value": "94"
#         },
#         {
#             "7d_click": "27",
#             "action_type": "mobile_app_install",
#             "value": "42"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post",
#             "value": "1"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "post_reaction",
#             "value": "4"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "3"
#         },
#         {
#             "7d_click": "2253",
#             "action_type": "omni_custom",
#             "value": "6580"
#         },
#         {
#             "7d_click": "561",
#             "action_type": "omni_activate_app",
#             "value": "1971"
#         },
#         {
#             "7d_click": "99",
#             "action_type": "page_engagement",
#             "value": "99"
#         },
#         {
#             "7d_click": "99",
#             "action_type": "post_engagement",
#             "value": "99"
#         },
#         {
#             "7d_click": "27",
#             "action_type": "omni_app_install",
#             "value": "42"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "2"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "view_content",
#             "value": "2"
#         }
#     ],
#     "campaign_id": "6197888719407",
#     "campaign_name": "\u80a1\u5e02\u7206\u6599\u540c\u5b78\u6703_\u6e2c\u8a66\u5c08\u7528_20200606(\u4e0b\u8f09)",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "377"
# }
# 籌碼K線_iOS_下載
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "886",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "3704"
#         },
#         {
#             "7d_click": "169",
#             "action_type": "link_click",
#             "value": "169"
#         },
#         {
#             "7d_click": "67",
#             "action_type": "mobile_app_install",
#             "value": "101"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "post_reaction",
#             "value": "7"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "886",
#             "action_type": "omni_activate_app",
#             "value": "3704"
#         },
#         {
#             "7d_click": "176",
#             "action_type": "page_engagement",
#             "value": "176"
#         },
#         {
#             "7d_click": "176",
#             "action_type": "post_engagement",
#             "value": "176"
#         },
#         {
#             "7d_click": "67",
#             "action_type": "omni_app_install",
#             "value": "101"
#         }
#     ],
#     "campaign_id": "6202362986607",
#     "campaign_name": "\u7c4c\u78bcK\u7dda_iOS_\u4e0b\u8f09",
#     "conversion_values": [
#         {
#             "7d_click": "3590",
#             "action_type": "subscribe_mobile_app",
#             "value": "3590"
#         },
#         {
#             "7d_click": "3590",
#             "action_type": "subscribe_total",
#             "value": "3590"
#         }
#     ],
#     "conversions": [
#         {
#             "7d_click": "1",
#             "action_type": "subscribe_mobile_app",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "subscribe_total",
#             "value": "1"
#         }
#     ],
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "2632"
# }
# 20200801_林恩如_AOS_下載_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "51",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "108"
#         },
#         {
#             "7d_click": "69",
#             "action_type": "link_click",
#             "value": "69"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "mobile_app_install",
#             "value": "20"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "action_type": "video_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "51",
#             "action_type": "omni_activate_app",
#             "value": "108"
#         },
#         {
#             "7d_click": "70",
#             "action_type": "page_engagement",
#             "value": "71"
#         },
#         {
#             "7d_click": "70",
#             "action_type": "post_engagement",
#             "value": "71"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "omni_app_install",
#             "value": "20"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6205092215407",
#     "campaign_name": "20200801_\u6797\u6069\u5982_AOS_\u4e0b\u8f09_\u8edf\u9ad4",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "319"
# }
# 20200801_林恩如_iOS_下載_軟體
#  <AdsInsights> {
#     "action_values": [
#         {
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "1831"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "1831"
#         }
#     ],
#     "actions": [
#         {
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "landing_page_view",
#             "value": "2"
#         },
#         {
#             "7d_click": "146",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "408"
#         },
#         {
#             "7d_click": "135",
#             "action_type": "link_click",
#             "value": "135"
#         },
#         {
#             "7d_click": "42",
#             "action_type": "mobile_app_install",
#             "value": "43"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "3"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "4"
#         },
#         {
#             "7d_click": "146",
#             "action_type": "omni_activate_app",
#             "value": "408"
#         },
#         {
#             "7d_click": "136",
#             "action_type": "page_engagement",
#             "value": "136"
#         },
#         {
#             "7d_click": "136",
#             "action_type": "post_engagement",
#             "value": "136"
#         },
#         {
#             "7d_click": "42",
#             "action_type": "omni_app_install",
#             "value": "43"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_add_to_cart",
#             "value": "3"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "purchase",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6205095831407",
#     "campaign_name": "20200801_\u6797\u6069\u5982_iOS_\u4e0b\u8f09_\u8edf\u9ad4",
#     "conversion_values": [
#         {
#             "action_type": "subscribe_total",
#             "value": "1700"
#         },
#         {
#             "action_type": "subscribe_mobile_app",
#             "value": "1700"
#         }
#     ],
#     "conversions": [
#         {
#             "7d_click": "2",
#             "action_type": "subscribe_total",
#             "value": "4"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "subscribe_mobile_app",
#             "value": "4"
#         }
#     ],
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "692"
# }
# 籌碼K線_Android_下載
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "145",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "725"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "onsite_conversion.post_save",
#             "value": "2"
#         },
#         {
#             "7d_click": "98",
#             "action_type": "link_click",
#             "value": "98"
#         },
#         {
#             "7d_click": "23",
#             "action_type": "mobile_app_install",
#             "value": "30"
#         },
#         {
#             "7d_click": "8",
#             "action_type": "post_reaction",
#             "value": "8"
#         },
#         {
#             "7d_click": "281",
#             "action_type": "video_view",
#             "value": "343"
#         },
#         {
#             "7d_click": "145",
#             "action_type": "omni_activate_app",
#             "value": "725"
#         },
#         {
#             "7d_click": "389",
#             "action_type": "page_engagement",
#             "value": "451"
#         },
#         {
#             "7d_click": "389",
#             "action_type": "post_engagement",
#             "value": "451"
#         },
#         {
#             "7d_click": "23",
#             "action_type": "omni_app_install",
#             "value": "30"
#         }
#     ],
#     "campaign_id": "6206406111407",
#     "campaign_name": "\u7c4c\u78bcK\u7dda_Android_\u4e0b\u8f09",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "1032"
# }
# 月老_APP下載_iOS_20200824
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "381",
#             "action_type": "app_custom_event.other",
#             "value": "432"
#         },
#         {
#             "7d_click": "67",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "79"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "42",
#             "action_type": "link_click",
#             "value": "42"
#         },
#         {
#             "7d_click": "26",
#             "action_type": "mobile_app_install",
#             "value": "26"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "381",
#             "action_type": "omni_custom",
#             "value": "432"
#         },
#         {
#             "7d_click": "67",
#             "action_type": "omni_activate_app",
#             "value": "79"
#         },
#         {
#             "7d_click": "44",
#             "action_type": "page_engagement",
#             "value": "44"
#         },
#         {
#             "7d_click": "44",
#             "action_type": "post_engagement",
#             "value": "44"
#         },
#         {
#             "7d_click": "26",
#             "action_type": "omni_app_install",
#             "value": "26"
#         }
#     ],
#     "campaign_id": "6207871699007",
#     "campaign_name": "\u6708\u8001_APP\u4e0b\u8f09_iOS_20200824",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "215"
# }
# 無聊詹_IOS_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "26",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "47"
#         },
#         {
#             "7d_click": "21",
#             "action_type": "link_click",
#             "value": "21"
#         },
#         {
#             "7d_click": "13",
#             "action_type": "mobile_app_install",
#             "value": "15"
#         },
#         {
#             "7d_click": "26",
#             "action_type": "omni_activate_app",
#             "value": "47"
#         },
#         {
#             "7d_click": "21",
#             "action_type": "page_engagement",
#             "value": "21"
#         },
#         {
#             "7d_click": "21",
#             "action_type": "post_engagement",
#             "value": "21"
#         },
#         {
#             "7d_click": "13",
#             "action_type": "omni_app_install",
#             "value": "15"
#         }
#     ],
#     "campaign_id": "6209479637407",
#     "campaign_name": "\u7121\u804a\u8a79_IOS_\u8edf\u9ad4",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "134"
# }
# 無聊詹_AOS_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "7"
#         },
#         {
#             "7d_click": "12",
#             "action_type": "link_click",
#             "value": "12"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "mobile_app_install",
#             "value": "3"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "omni_activate_app",
#             "value": "7"
#         },
#         {
#             "7d_click": "13",
#             "action_type": "page_engagement",
#             "value": "13"
#         },
#         {
#             "7d_click": "13",
#             "action_type": "post_engagement",
#             "value": "13"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_app_install",
#             "value": "3"
#         }
#     ],
#     "campaign_id": "6209480612607",
#     "campaign_name": "\u7121\u804a\u8a79_AOS_\u8edf\u9ad4",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "63"
# }
# 20200918_籌碼K線_iOS_下載
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "279",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "999"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "onsite_conversion.post_save",
#             "value": "2"
#         },
#         {
#             "7d_click": "64",
#             "action_type": "link_click",
#             "value": "64"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "mobile_app_install",
#             "value": "25"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "post_reaction",
#             "value": "2"
#         },
#         {
#             "7d_click": "124",
#             "action_type": "video_view",
#             "value": "282"
#         },
#         {
#             "7d_click": "279",
#             "action_type": "omni_activate_app",
#             "value": "999"
#         },
#         {
#             "7d_click": "192",
#             "action_type": "page_engagement",
#             "value": "350"
#         },
#         {
#             "7d_click": "192",
#             "action_type": "post_engagement",
#             "value": "350"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "omni_app_install",
#             "value": "25"
#         }
#     ],
#     "campaign_id": "6213307234807",
#     "campaign_name": "20200918_\u7c4c\u78bcK\u7dda_iOS_\u4e0b\u8f09",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "495"
# }
# 20200918_籌碼K線_Android_下載
#  <AdsInsights> {
#     "action_values": [
#         {
#             "action_type": "app_custom_event.fb_mobile_purchase",
#             "value": "2090"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "2090"
#         }
#     ],
#     "actions": [
#         {
#             "action_type": "app_custom_event.fb_mobile_purchase",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "1"
#         },
#         {
#             "7d_click": "146",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "840"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "91",
#             "action_type": "link_click",
#             "value": "91"
#         },
#         {
#             "7d_click": "24",
#             "action_type": "mobile_app_install",
#             "value": "33"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "8",
#             "action_type": "post_reaction",
#             "value": "8"
#         },
#         {
#             "7d_click": "760",
#             "action_type": "video_view",
#             "value": "1086"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "1"
#         },
#         {
#             "7d_click": "146",
#             "action_type": "omni_activate_app",
#             "value": "840"
#         },
#         {
#             "7d_click": "860",
#             "action_type": "page_engagement",
#             "value": "1186"
#         },
#         {
#             "7d_click": "860",
#             "action_type": "post_engagement",
#             "value": "1186"
#         },
#         {
#             "7d_click": "24",
#             "action_type": "omni_app_install",
#             "value": "33"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "purchase",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6213308986807",
#     "campaign_name": "20200918_\u7c4c\u78bcK\u7dda_Android_\u4e0b\u8f09",
#     "conversion_values": [
#         {
#             "action_type": "subscribe_total",
#             "value": "2090"
#         },
#         {
#             "action_type": "subscribe_mobile_app",
#             "value": "2090"
#         }
#     ],
#     "conversions": [
#         {
#             "action_type": "subscribe_total",
#             "value": "1"
#         },
#         {
#             "action_type": "subscribe_mobile_app",
#             "value": "1"
#         }
#     ],
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "806"
# }
# 20200922_籌碼K線_Android_下載
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "114",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "570"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "88",
#             "action_type": "link_click",
#             "value": "88"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "mobile_app_install",
#             "value": "23"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "post_reaction",
#             "value": "2"
#         },
#         {
#             "7d_click": "53",
#             "action_type": "video_view",
#             "value": "88"
#         },
#         {
#             "7d_click": "114",
#             "action_type": "omni_activate_app",
#             "value": "570"
#         },
#         {
#             "7d_click": "145",
#             "action_type": "page_engagement",
#             "value": "180"
#         },
#         {
#             "7d_click": "145",
#             "action_type": "post_engagement",
#             "value": "180"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "omni_app_install",
#             "value": "23"
#         }
#     ],
#     "campaign_id": "6214103320607",
#     "campaign_name": "20200922_\u7c4c\u78bcK\u7dda_Android_\u4e0b\u8f09",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "503"
# }
# 20200922_艾蜜莉APP_IOS_下載_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "3",
#             "action_type": "landing_page_view",
#             "value": "3"
#         },
#         {
#             "7d_click": "633",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "1597"
#         },
#         {
#             "7d_click": "215",
#             "action_type": "link_click",
#             "value": "215"
#         },
#         {
#             "7d_click": "107",
#             "action_type": "mobile_app_install",
#             "value": "121"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post",
#             "value": "1"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "post_reaction",
#             "value": "5"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "10"
#         },
#         {
#             "7d_click": "633",
#             "action_type": "omni_activate_app",
#             "value": "1597"
#         },
#         {
#             "7d_click": "221",
#             "action_type": "page_engagement",
#             "value": "221"
#         },
#         {
#             "7d_click": "221",
#             "action_type": "post_engagement",
#             "value": "221"
#         },
#         {
#             "7d_click": "107",
#             "action_type": "omni_app_install",
#             "value": "121"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "view_content",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6214217575407",
#     "campaign_name": "20200922_\u827e\u871c\u8389APP_IOS_\u4e0b\u8f09_\u8edf\u9ad4",
#     "conversion_values": [
#         {
#             "action_type": "subscribe_total",
#             "value": "390"
#         },
#         {
#             "action_type": "subscribe_mobile_app",
#             "value": "390"
#         }
#     ],
#     "conversions": [
#         {
#             "action_type": "subscribe_total",
#             "value": "1"
#         },
#         {
#             "action_type": "subscribe_mobile_app",
#             "value": "1"
#         }
#     ],
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "1048"
# }
# 20200922_艾蜜莉APP_Android_下載_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "7d_click": "158",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "502"
#         },
#         {
#             "7d_click": "128",
#             "action_type": "link_click",
#             "value": "128"
#         },
#         {
#             "7d_click": "40",
#             "action_type": "mobile_app_install",
#             "value": "47"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "2"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "post_reaction",
#             "value": "4"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "video_view",
#             "value": "120"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "8"
#         },
#         {
#             "7d_click": "158",
#             "action_type": "omni_activate_app",
#             "value": "502"
#         },
#         {
#             "7d_click": "134",
#             "action_type": "page_engagement",
#             "value": "252"
#         },
#         {
#             "7d_click": "134",
#             "action_type": "post_engagement",
#             "value": "252"
#         },
#         {
#             "7d_click": "40",
#             "action_type": "omni_app_install",
#             "value": "47"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "2"
#         }
#     ],
#     "campaign_id": "6214225214407",
#     "campaign_name": "20200922_\u827e\u871c\u8389APP_Android_\u4e0b\u8f09_\u8edf\u9ad4",
#     "conversion_values": [
#         {
#             "7d_click": "390",
#             "action_type": "subscribe_total",
#             "value": "390"
#         },
#         {
#             "7d_click": "390",
#             "action_type": "subscribe_mobile_app",
#             "value": "390"
#         }
#     ],
#     "conversions": [
#         {
#             "7d_click": "1",
#             "action_type": "subscribe_total",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "subscribe_mobile_app",
#             "value": "1"
#         }
#     ],
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "770"
# }
# 股市爆料同學會_Henry_自動化應用程式廣告Test_20200923_Android
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "5",
#             "action_type": "app_custom_event.other",
#             "value": "55"
#         },
#         {
#             "7d_click": "120",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "459"
#         },
#         {
#             "7d_click": "19",
#             "action_type": "link_click",
#             "value": "19"
#         },
#         {
#             "7d_click": "11",
#             "action_type": "mobile_app_install",
#             "value": "14"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "42",
#             "action_type": "video_view",
#             "value": "48"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "omni_custom",
#             "value": "55"
#         },
#         {
#             "7d_click": "120",
#             "action_type": "omni_activate_app",
#             "value": "459"
#         },
#         {
#             "7d_click": "62",
#             "action_type": "page_engagement",
#             "value": "68"
#         },
#         {
#             "7d_click": "62",
#             "action_type": "post_engagement",
#             "value": "68"
#         },
#         {
#             "7d_click": "11",
#             "action_type": "omni_app_install",
#             "value": "14"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "1"
#         },
#         {
#             "action_type": "purchase",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6214317545207",
#     "campaign_name": "\u80a1\u5e02\u7206\u6599\u540c\u5b78\u6703_Henry_\u81ea\u52d5\u5316\u61c9\u7528\u7a0b\u5f0f\u5ee3\u544aTest_20200923_Android",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "62"
# }
# 股市爆料同學會_理財綜合(非儲備受眾)_20200923
#  <AdsInsights> {
#     "actions": [
#         {
#             "action_type": "app_custom_event.other",
#             "value": "53"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "15"
#         },
#         {
#             "7d_click": "9",
#             "action_type": "link_click",
#             "value": "9"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "mobile_app_install",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "video_view",
#             "value": "3"
#         },
#         {
#             "action_type": "omni_custom",
#             "value": "53"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "omni_activate_app",
#             "value": "15"
#         },
#         {
#             "7d_click": "10",
#             "action_type": "page_engagement",
#             "value": "12"
#         },
#         {
#             "7d_click": "10",
#             "action_type": "post_engagement",
#             "value": "12"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_app_install",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6214355839407",
#     "campaign_name": "\u80a1\u5e02\u7206\u6599\u540c\u5b78\u6703_\u7406\u8ca1\u7d9c\u5408(\u975e\u5132\u5099\u53d7\u773e)_20200923",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "7"
# }
# 股市爆料同學會_Henry_自動化應用程式廣告Test_20200923_iOS
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2620",
#             "action_type": "app_custom_event.other",
#             "value": "11077"
#         },
#         {
#             "7d_click": "496",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "2361"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "118",
#             "action_type": "link_click",
#             "value": "118"
#         },
#         {
#             "7d_click": "41",
#             "action_type": "mobile_app_install",
#             "value": "62"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "post_reaction",
#             "value": "5"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "video_view",
#             "value": "8"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "1"
#         },
#         {
#             "7d_click": "2620",
#             "action_type": "omni_custom",
#             "value": "11077"
#         },
#         {
#             "7d_click": "496",
#             "action_type": "omni_activate_app",
#             "value": "2361"
#         },
#         {
#             "7d_click": "130",
#             "action_type": "page_engagement",
#             "value": "132"
#         },
#         {
#             "7d_click": "130",
#             "action_type": "post_engagement",
#             "value": "132"
#         },
#         {
#             "7d_click": "41",
#             "action_type": "omni_app_install",
#             "value": "62"
#         }
#     ],
#     "campaign_id": "6214384487007",
#     "campaign_name": "\u80a1\u5e02\u7206\u6599\u540c\u5b78\u6703_Henry_\u81ea\u52d5\u5316\u61c9\u7528\u7a0b\u5f0f\u5ee3\u544aTest_20200923_iOS",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "498"
# }
# 期貨電子盤_下載_Android(舊)
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "32",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "75"
#         },
#         {
#             "7d_click": "10",
#             "action_type": "link_click",
#             "value": "10"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "mobile_app_install",
#             "value": "4"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "omni_activate_app",
#             "value": "75"
#         },
#         {
#             "7d_click": "11",
#             "action_type": "page_engagement",
#             "value": "11"
#         },
#         {
#             "7d_click": "11",
#             "action_type": "post_engagement",
#             "value": "11"
#         },
#         {
#             "7d_click": "4",
#             "action_type": "omni_app_install",
#             "value": "4"
#         }
#     ],
#     "campaign_id": "6214445913607",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_Android(\u820a)",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "33"
# }
# 丹尼爾_AOS_下載_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "4"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "link_click",
#             "value": "6"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "mobile_app_install",
#             "value": "3"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_activate_app",
#             "value": "4"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "page_engagement",
#             "value": "6"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "post_engagement",
#             "value": "6"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_app_install",
#             "value": "3"
#         }
#     ],
#     "campaign_id": "6214596146807",
#     "campaign_name": "\u4e39\u5c3c\u723e_AOS_\u4e0b\u8f09_\u8edf\u9ad4",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "46"
# }
# 丹尼爾_IOS_下載_軟體
#  <AdsInsights> {
#     "action_values": [
#         {
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "299"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "299"
#         }
#     ],
#     "actions": [
#         {
#             "action_type": "offsite_conversion.fb_pixel_purchase",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_purchase",
#             "value": "1"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "13"
#         },
#         {
#             "7d_click": "13",
#             "action_type": "link_click",
#             "value": "13"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "mobile_app_install",
#             "value": "3"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "1"
#         },
#         {
#             "7d_click": "7",
#             "action_type": "omni_activate_app",
#             "value": "13"
#         },
#         {
#             "7d_click": "14",
#             "action_type": "page_engagement",
#             "value": "14"
#         },
#         {
#             "7d_click": "14",
#             "action_type": "post_engagement",
#             "value": "14"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "omni_app_install",
#             "value": "3"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "purchase",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6214596424007",
#     "campaign_name": "\u4e39\u5c3c\u723e_IOS_\u4e0b\u8f09_\u8edf\u9ad4",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "70"
# }
# 武財神_APP下載_Android_2020928_自動化測試
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1807",
#             "action_type": "app_custom_event.other",
#             "value": "2725"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "comment",
#             "value": "1"
#         },
#         {
#             "7d_click": "328",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "629"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "257",
#             "action_type": "link_click",
#             "value": "257"
#         },
#         {
#             "7d_click": "83",
#             "action_type": "mobile_app_install",
#             "value": "98"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post",
#             "value": "1"
#         },
#         {
#             "7d_click": "22",
#             "action_type": "post_reaction",
#             "value": "22"
#         },
#         {
#             "7d_click": "1807",
#             "action_type": "omni_custom",
#             "value": "2725"
#         },
#         {
#             "7d_click": "282",
#             "action_type": "page_engagement",
#             "value": "282"
#         },
#         {
#             "7d_click": "282",
#             "action_type": "post_engagement",
#             "value": "282"
#         },
#         {
#             "7d_click": "328",
#             "action_type": "omni_activate_app",
#             "value": "629"
#         },
#         {
#             "7d_click": "83",
#             "action_type": "omni_app_install",
#             "value": "98"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "2"
#         },
#         {
#             "action_type": "view_content",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6215360310207",
#     "campaign_name": "\u6b66\u8ca1\u795e_APP\u4e0b\u8f09_Android_2020928_\u81ea\u52d5\u5316\u6e2c\u8a66",
#     "date_start": "2020-10-16",
#     "date_stop": "2020-10-16",
#     "objective": "APP_INSTALLS",
#     "spend": "1059"
# }
# 股市爆料同學會_理財受眾A(非儲備受眾)_20201007
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "5",
#             "action_type": "landing_page_view",
#             "value": "5"
#         },
#         {
#             "7d_click": "7808",
#             "action_type": "app_custom_event.other",
#             "value": "24046"
#         },
#         {
#             "7d_click": "2000",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "7449"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "502",
#             "action_type": "link_click",
#             "value": "502"
#         },
#         {
#             "7d_click": "137",
# ...
#             "value": "17"
#         },
#         {
#             "7d_click": "194",
#             "action_type": "landing_page_view",
#             "value": "194"
#         },
#         {
#             "7d_click": "265",
#             "action_type": "link_click",
#             "value": "265"
#         },
#         {
#             "7d_click": "69",
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "79"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "post",
#             "value": "2"
#         },
#         {
#             "7d_click": "29",
#             "action_type": "post_reaction",
#             "value": "29"
#         },
#         {
#             "7d_click": "49",
#             "action_type": "video_view",
#             "value": "4694"
#         },
#         {
#             "7d_click": "69",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "84"
#         },
#         {
#             "7d_click": "345",
#             "action_type": "page_engagement",
#             "value": "4990"
#         },
#         {
#             "7d_click": "345",
#             "action_type": "post_engagement",
#             "value": "4990"
#         },
#         {
#             "7d_click": "69",
#             "action_type": "omni_add_to_cart",
#             "value": "79"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "69",
#             "action_type": "add_to_cart",
#             "value": "79"
#         },
#         {
#             "7d_click": "8",
#             "action_type": "purchase",
#             "value": "17"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "view_content",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.custom.419162548761345",
#             "value": "2"
#         },
#         {
#             "action_type": "offsite_conversion.custom.451600008878152",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.custom.549452585618599",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.custom.999210003854000",
#             "value": "1"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_custom",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6221855932407",
#     "campaign_name": "\u7c4c\u78bcK\u7dda-\u96d911\u8f49\u63db11/10",
#     "conversions": [
#         {
#             "action_type": "start_trial_total",
#             "value": "1"
#         },
#         {
#             "action_type": "start_trial_website",
#             "value": "1"
#         }
#     ],
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "CONVERSIONS",
#     "spend": "7734"
# }
# 20201110_艾蜜莉下載_IOS_自動化廣告_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "3",
#             "action_type": "landing_page_view",
#             "value": "3"
#         },
#         {
#             "7d_click": "178",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "243"
#         },
#         {
#             "7d_click": "238",
#             "action_type": "link_click",
#             "value": "238"
#         },
#         {
#             "7d_click": "39",
#             "action_type": "mobile_app_install",
#             "value": "44"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "9",
#             "action_type": "post_reaction",
#             "value": "9"
#         },
#         {
#             "action_type": "video_view",
#             "value": "84"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "178",
#             "action_type": "omni_activate_app",
#             "value": "243"
#         },
#         {
#             "7d_click": "247",
#             "action_type": "page_engagement",
#             "value": "331"
#         },
#         {
#             "7d_click": "247",
#             "action_type": "post_engagement",
#             "value": "331"
#         },
#         {
#             "7d_click": "39",
#             "action_type": "omni_app_install",
#             "value": "44"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "omni_view_content",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "add_to_cart",
#             "value": "3"
#         },
#         {
#             "action_type": "view_content",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6221856618207",
#     "campaign_name": "20201110_\u827e\u871c\u8389\u4e0b\u8f09_IOS_\u81ea\u52d5\u5316\u5ee3\u544a_\u8edf\u9ad4",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "909"
# }
# 20201110_艾蜜莉下載_Android_自動化廣告_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2",
#             "action_type": "landing_page_view",
#             "value": "2"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "comment",
#             "value": "2"
#         },
#         {
#             "7d_click": "247",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "283"
#         },
#         {
#             "7d_click": "282",
#             "action_type": "link_click",
#             "value": "282"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "mobile_app_install",
#             "value": "35"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "1"
#         },
#         {
#             "7d_click": "8",
#             "action_type": "post_reaction",
#             "value": "8"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "video_view",
#             "value": "50"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "294",
#             "action_type": "page_engagement",
#             "value": "342"
#         },
#         {
#             "7d_click": "294",
#             "action_type": "post_engagement",
#             "value": "342"
#         },
#         {
#             "7d_click": "247",
#             "action_type": "omni_activate_app",
#             "value": "283"
#         },
#         {
#             "7d_click": "32",
#             "action_type": "omni_app_install",
#             "value": "35"
#         },
#         {
#             "action_type": "omni_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "add_to_cart",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6221859691007",
#     "campaign_name": "20201110_\u827e\u871c\u8389\u4e0b\u8f09_Android_\u81ea\u52d5\u5316\u5ee3\u544a_\u8edf\u9ad4",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "947"
# }
# 期貨電子盤_下載_IOS
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "5",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "5"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "link_click",
#             "value": "3"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "mobile_app_install",
#             "value": "2"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "omni_activate_app",
#             "value": "5"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "page_engagement",
#             "value": "3"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "post_engagement",
#             "value": "3"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "omni_app_install",
#             "value": "2"
#         }
#     ],
#     "campaign_id": "6222013881607",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_IOS",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "74"
# }
# 阿勳雙11瘋了季訂閱銷售轉換
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2",
#             "action_type": "landing_page_view",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "onsite_conversion.post_save",
#             "value": "1"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "link_click",
#             "value": "5"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "page_engagement",
#             "value": "6"
#         },
#         {
#             "7d_click": "6",
#             "action_type": "post_engagement",
#             "value": "6"
#         }
#     ],
#     "campaign_id": "6222036719407",
#     "campaign_name": "\u963f\u52f3\u96d911\u760b\u4e86\u5b63\u8a02\u95b1\u92b7\u552e\u8f49\u63db",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "CONVERSIONS",
#     "spend": "127"
# }
# 期貨電子盤_下載_Android
#  <AdsInsights> {
#     "campaign_id": "6222170804007",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_Android",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "9"
# }
# 期貨電子盤_下載_IOS
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "1",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "link_click",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "mobile_app_install",
#             "value": "1"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_activate_app",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "page_engagement",
#             "value": "2"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "post_engagement",
#             "value": "2"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_app_install",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6222172492007",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_IOS",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "22"
# }
# 期貨電子盤_下載_Android
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "5",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "5"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "link_click",
#             "value": "3"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "mobile_app_install",
#             "value": "1"
#         },
#         {
#             "7d_click": "2",
#             "action_type": "offsite_conversion.custom.413934298800769",
#             "value": "2"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "omni_activate_app",
#             "value": "5"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "page_engagement",
#             "value": "3"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "post_engagement",
#             "value": "3"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "omni_app_install",
#             "value": "1"
#         }
#     ],
#     "campaign_id": "6222174093007",
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_Android",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "27"
# }
# 順流小畢_1113(轉換)_商務艙推廣
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "5",
#             "action_type": "landing_page_view",
#             "value": "5"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "link_click",
#             "value": "5"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "page_engagement",
#             "value": "5"
#         },
#         {
#             "7d_click": "5",
#             "action_type": "post_engagement",
#             "value": "5"
#         }
#     ],
#     "campaign_id": "6222333931007",
#     "campaign_name": "\u9806\u6d41\u5c0f\u7562_1113(\u8f49\u63db)_\u5546\u52d9\u8259\u63a8\u5ee3",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "CONVERSIONS",
#     "spend": "71"
# }
# 20201113_股人阿勳_下載_Android_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "2",
#             "action_type": "comment",
#             "value": "2"
#         },
#         {
#             "7d_click": "28",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "40"
#         },
#         {
#             "7d_click": "51",
#             "action_type": "link_click",
#             "value": "51"
#         },
#         {
#             "7d_click": "12",
#             "action_type": "mobile_app_install",
#             "value": "21"
#         },
#         {
#             "7d_click": "1",
#             "action_type": "post_reaction",
#             "value": "1"
#         },
#         {
#             "7d_click": "54",
#             "action_type": "page_engagement",
#             "value": "54"
#         },
#         {
#             "7d_click": "54",
#             "action_type": "post_engagement",
#             "value": "54"
#         },
#         {
#             "7d_click": "28",
#             "action_type": "omni_activate_app",
#             "value": "40"
#         },
#         {
#             "7d_click": "12",
#             "action_type": "omni_app_install",
#             "value": "21"
#         }
#     ],
#     "campaign_id": "6222334664607",
#     "campaign_name": "20201113_\u80a1\u4eba\u963f\u52f3_\u4e0b\u8f09_Android_\u8edf\u9ad4",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "473"
# }
# 20201113_股人阿勳_下載_IOS_軟體
#  <AdsInsights> {
#     "actions": [
#         {
#             "7d_click": "134",
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "141"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "onsite_conversion.post_save",
#             "value": "3"
#         },
#         {
#             "7d_click": "99",
#             "action_type": "link_click",
#             "value": "99"
#         },
#         {
#             "7d_click": "38",
#             "action_type": "mobile_app_install",
#             "value": "40"
#         },
#         {
#             "7d_click": "3",
#             "action_type": "post_reaction",
#             "value": "3"
#         },
#         {
#             "7d_click": "134",
#             "action_type": "omni_activate_app",
#             "value": "141"
#         },
#         {
#             "7d_click": "105",
#             "action_type": "page_engagement",
#             "value": "105"
#         },
#         {
#             "7d_click": "105",
#             "action_type": "post_engagement",
#             "value": "105"
#         },
#         {
#             "7d_click": "38",
#             "action_type": "omni_app_install",
#             "value": "40"
#         }
#     ],
#     "campaign_id": "6222338598207",
#     "campaign_name": "20201113_\u80a1\u4eba\u963f\u52f3_\u4e0b\u8f09_IOS_\u8edf\u9ad4",
#     "date_start": "2020-11-13",
#     "date_stop": "2020-11-13",
#     "objective": "APP_INSTALLS",
#     "spend": "507"
# }
# finish_1
# --- 19.320980310440063 seconds ---

# %%
for cv in acc_insight['conversions']:
    print(cv)
    print((cv['7d_click'] in cv))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7f3f1add6bd> in <module>
# ----> 1 for cv in acc_insight['conversions']:
#       2     print(cv)
#       3     print((cv['7d_click'] in cv))
#
# NameError: name 'acc_insight' is not defined

# %%
from datetime import datetime, timedelta

time = input('Enter start time YYYY-MM-DD: ')
start_time = datetime.strptime(time, '%Y-%m-%d')
print(start_time)

obj_time = datetime.now().strftime('%Y%m%d')
# 一個月的公差
time_period = timedelta(weeks = 4)

# search_period = 

# for i in 

# 用於計算時間差
# start_time = datetime.now() - time_period

# 用於主程式的 time_range
# start_time.strftime('%Y-%m-%d')
# Out:
# Enter start time YYYY-MM-DD: 1998-08-05
# 1998-08-05 00:00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-801a30173d2c> in <module>
#       5 print(start_time)
#       6
# ----> 7 obj_time = datetime.now().strftime('%Y%m%d') - 7
#       8 # 一個月的公差
#       9 time_period = timedelta(weeks = 4)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
import time
from datetime import datetime, timedelta

obj_time = input('YYYY-MM-DD: ')
obj_time = obj_time.split('-')
print(obj_time)
print(type(obj_time[0]))
time.struct_time(tm_year = int(obj_time[0]),\
                 tm_mon = int(obj_time[1]),\
                 tm_mday = int(obj_time[2]))
# Out:
# YYYY-MM-DD: 1998-08-05
# ['1998', '08', '05']
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-6f993a753fe1> in <module>
#       6 print(obj_time)
#       7 print(type(obj_time[0]))
# ----> 8 time.struct_time(tm_year = int(obj_time[0]),\
#       9                  tm_mon = int(obj_time[1]),\
#      10                  tm_mday = int(obj_time[2]))
#
# TypeError: structseq() takes at most 2 keyword arguments (3 given)

# %%
from datetime import datetime, timedelta

time = input('Enter start time YYYY-MM-DD: ')
start_time = datetime.strptime(time, '%Y-%m-%d')
print(start_time.strftime('%Y-%m-%d'))
# Out:
# Enter start time YYYY-MM-DD: 1998-08-05
# 1998-08-05

# %%
print(start_time.strftime('%Y-%m-%d') - timedelta(weeks = 4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-846320e86954> in <module>
# ----> 1 print(start_time.strftime('%Y-%m-%d') - timedelta(weeks = 4))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'datetime.timedelta'

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights
from facebook_business.api import FacebookAdsApi
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import csv
import time

# Initialize the access_token
access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# Insight API中的fields資料(控制需要的欄位資料)
fields = [
    'spend',
    'campaign_name',
    'adset_name',
    'campaign_id',
    'actions',
    'objective',
    'action_values',  
    'conversions',
    'conversion_values',
]
# -----------------------------------------------------------

# 先確立到底要執行多少次迴圈(- 4weeks)
# obj_time = input('Enter the time-start>> YYYY-MM-DD: ')

# 建立CSV資料，並將Business SDK獲得的資料儲存
outfn = '{}_fb.csv'.format('FB_Ads_Marketing_Data')


# 開始時間
week_minus = timedelta(weeks = 1)
start_time = datetime.now() - week_minus
end_time = start_time + relativedelta(months = -1)

for i in range(2):
    # 用於主程式的 time_range
    # start_time.strftime('%Y-%m-%d')

    # Insight API中的fields資料(控制日期條件、資料的層級)
    params = {
        'time_range': {
                    'since': end_time.strftime('%Y-%m-%d'),\
                    'until': start_time.strftime('%Y-%m-%d') 
        }, 

        'level': {'campaign'},
        'time_increment': '1',

        # Default 歸因(目前確認和廣告面板上面的相同 7天點擊 + 7天瀏覽)
        # 'use_account_attribution_setting': 'True',

        # 自己設定的歸因(和廣告預設值有落差)
        'action_attribution_windows': {'7d_click'},
    }
    # -----------------------------------------------------------


    acc_insights = AdAccount(ad_account_id).get_insights(
        fields = fields,
        params = params,
    )

    # 寫入資料庫-----------------------------------------------------
    # 日報
    # outfn = '{%Y-%m-%d}.database.csv'.format(datetime.today())
    run_time = time.time()


    title_row = ['Campaign_name', 'Objective', 'Amount_spent(NTD)', \
                 'Amount_install', \
                 'Amount_purchase' , 'Purchase_Conversion_Value',\
                 'Amount_subscribe', 'Subscribe_Conversion_Value', \
                 'Reporting_date']

    begin_count = 0

    if begin_count == 0:
        with open(outfn, 'w', newline = '') as csvout:
            csvWriter = csv.writer(csvout)
            csvWriter.writerow(title_row)
            
            begin_count += 1
            for acc_insight in acc_insights:     
                Campaign_name = ''
                Amount_spent = ''
                Objective = ''
                Amount_subscribe = '' 
                Subscribe_Conversion_Value = ''
                Amount_install = '' 
                Amount_purchase = ''    
                Purchase_Conversion_Value = ''
                Reporting_date = ''

                # insights/campaign_name得到 "產品包名稱"
                if 'campaign_name' in acc_insight:
                    Campaign_name = acc_insight['campaign_name']

                # insights/spend得到 "總支出成本"
                if 'spend' in acc_insight:    
                    Amount_spent = acc_insight['spend']

                # insights/objective得到 "廣告目標"
                if 'objective' in acc_insight:
                    Objective = acc_insight['objective']

                # insights/date_stop得到 "報表終止日期"
                if 'date_stop' in acc_insight:
                    Reporting_date = acc_insight['date_stop']

                # insights/actions得到 "軟體下載數/課程購買數"
                if 'actions' in acc_insight:
                    for action in acc_insight['actions']:
                        if action['action_type'] == 'mobile_app_install': 
                            Amount_install = action['value']
                        if action['action_type'] == 'purchase':
                            Amount_purchase = action['value']

                # insights/action_values得到 "購買轉換價值"
                if 'action_values' in acc_insight:
                    for ac_values in acc_insight['action_values']:
                        if ac_values['action_type'] == 'omni_purchase':
                            Purchase_Conversion_Value = ac_values['value']

                # insights/conversions得到 "訂閱數"
                if 'conversions' in acc_insight:
                    for cv in acc_insight['conversions']:
                        if cv['action_type'] == 'subscribe_total':
                            try:
                                Amount_subscribe = cv['7d_click']
                            except:
                                Amount_subscribe = cv['value']

                # insights/conversion_values得到 "訂閱轉換價值"             
                if 'conversion_values' in acc_insight:
                    for cv_values in acc_insight['conversion_values']:
                        if cv_values['action_type'] == 'subscribe_total':
                            try:
                                Subscribe_Conversion_Value = cv_values['7d_click']
                            except:
                                Subscribe_Conversion_Value = cv_values['value']

                csvWriter.writerow([
                    Campaign_name,
                    Objective,
                    Amount_spent,
                    Amount_install, 
                    Amount_purchase,
                    Purchase_Conversion_Value,
                    Amount_subscribe,
                    Subscribe_Conversion_Value,
                    Reporting_date,
                ])
        print('finish{}'.format(begin_count))
        time.sleep(120)
                #列印出資料數值，給予比對             
#                 print(acc_insight['campaign_name'] + '\n', acc_insight)
        
    else:
        with open(outfn, 'a', newline = '') as csvout:
            csvWriter = csv.writer(csvout)
            
            begin_count += 1
            for acc_insight in acc_insights:     
                Campaign_name = ''
                Amount_spent = ''
                Objective = ''
                Amount_subscribe = '' 
                Subscribe_Conversion_Value = ''
                Amount_install = '' 
                Amount_purchase = ''    
                Purchase_Conversion_Value = ''
                Reporting_date = ''

                # insights/campaign_name得到 "產品包名稱"
                if 'campaign_name' in acc_insight:
                    Campaign_name = acc_insight['campaign_name']

                # insights/spend得到 "總支出成本"
                if 'spend' in acc_insight:    
                    Amount_spent = acc_insight['spend']

                # insights/objective得到 "廣告目標"
                if 'objective' in acc_insight:
                    Objective = acc_insight['objective']

                # insights/date_stop得到 "報表終止日期"
                if 'date_stop' in acc_insight:
                    Reporting_date = acc_insight['date_stop']

                # insights/actions得到 "軟體下載數/課程購買數"
                if 'actions' in acc_insight:
                    for action in acc_insight['actions']:
                        if action['action_type'] == 'mobile_app_install': 
                            Amount_install = action['value']
                        if action['action_type'] == 'purchase':
                            Amount_purchase = action['value']

                # insights/action_values得到 "購買轉換價值"
                if 'action_values' in acc_insight:
                    for ac_values in acc_insight['action_values']:
                        if ac_values['action_type'] == 'omni_purchase':
                            Purchase_Conversion_Value = ac_values['value']

                # insights/conversions得到 "訂閱數"
                if 'conversions' in acc_insight:
                    for cv in acc_insight['conversions']:
                        if cv['action_type'] == 'subscribe_total':
                            try:
                                Amount_subscribe = cv['7d_click']
                            except:
                                Amount_subscribe = cv['value']

                # insights/conversion_values得到 "訂閱轉換價值"             
                if 'conversion_values' in acc_insight:
                    for cv_values in acc_insight['conversion_values']:
                        if cv_values['action_type'] == 'subscribe_total':
                            try:
                                Subscribe_Conversion_Value = cv_values['7d_click']
                            except:
                                Subscribe_Conversion_Value = cv_values['value']

                csvWriter.writerow([
                    Campaign_name,
                    Objective,
                    Amount_spent,
                    Amount_install, 
                    Amount_purchase,
                    Purchase_Conversion_Value,
                    Amount_subscribe,
                    Subscribe_Conversion_Value,
                    Reporting_date,
                ])

                #列印出資料數值，給予比對             
#                 print(acc_insight['campaign_name'] + '\n', acc_insight)
            start_time += relativedelta(months = -1) - timedelta(days = 1)
            end_time += relativedelta(months = -1)

        # flag確立program完整結束
        print('finish{}'.format(begin_count))
        time.sleep(120)
print('--- %s seconds ---' % (time.time() - run_time))
print('finish End')
# Out:
# ---------------------------------------------------------------------------
# FacebookRequestError                      Traceback (most recent call last)
# <ipython-input-3-aa393face9ea> in <module>
#      66     acc_insights = AdAccount(ad_account_id).get_insights(
#      67         fields = fields,
# ---> 68         params = params,
#      69     )
#      70
#
# D:\Anaconda_JupyterNotebook\lib\site-packages\facebook_business\adobjects\adaccount.py in get_insights(self, fields, params, is_async, batch, success, failure, pending)
#    2732         else:
#    2733             self.assure_call()
# -> 2734             return request.execute()
#    2735
#    2736     def get_insights_async(self, fields=None, params=None, batch=None, success=None, failure=None, pending=False):
#
# D:\Anaconda_JupyterNotebook\lib\site-packages\facebook_business\api.py in execute(self)
#     669                 endpoint=self._endpoint,
#     670             )
# --> 671             cursor.load_next_page()
#     672             return cursor
#     673         if self._fields:
#
# D:\Anaconda_JupyterNotebook\lib\site-packages\facebook_business\api.py in load_next_page(self)
#     836             'GET',
#     837             self._path,
# --> 838             params=self.params,
#     839         )
#     840         response = response_obj.json()
#
# D:\Anaconda_JupyterNotebook\lib\site-packages\facebook_business\api.py in call(self, method, path, params, headers, files, url_override, api_version)
#     342
#     343         if fb_response.is_failure():
# --> 344             raise fb_response.error()
#     345
#     346         self._num_requests_succeeded += 1
#
# FacebookRequestError:
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v8.0/act_132799196821088/insights
#   Params:  {'time_range': '{"since":"2020-10-13","until":"2020-11-13"}', 'level': {'campaign'}, 'time_increment': '1', 'action_attribution_windows': {'7d_click'}, 'fields': 'spend,campaign_name,adset_name,campaign_id,actions,objective,action_values,conversions,conversion_values'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "(#80000) There have been too many calls from this ad-account. Wait a bit and try again. For more info, please refer to https://developers.facebook.com/docs/graph-api/overview/rate-limiting.",
#         "type": "OAuthException",
#         "code": 80000,
#         "error_subcode": 2446079,
#         "fbtrace_id": "A3f3zecmgd8YKAXvKIJ31EV"
#       }
#     }

# %%
from dateutil.relativedelta import relativedelta
from datetime import date

six_months = date.today() + relativedelta(months = -1)
print(six_months.strftime('%Y-%m-%d'))
# Out:
# 2020-05-20

# %%
outfn_1 = '{}_fb.csv'.format('test')

with open(outfn_1, 'a+', newline = '') as csvout:
    csvWriter = csv.writer(csvout)
    csvWriter =
# Out:
#   File "<ipython-input-1-035e34553c5f>", line 5
#     csvWriter =
#                 ^
# SyntaxError: invalid syntax
