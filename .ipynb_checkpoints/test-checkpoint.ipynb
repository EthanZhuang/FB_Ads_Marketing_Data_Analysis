# %%
# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights
from facebook_business.api import FacebookAdsApi
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import csv
import time
import pandas as pd
import numpy as np
import pyodbc
import logging
import traceback, sys
import smtplib
from email.mime.text import MIMEText
import socket

# %%
# 連線SQL
DBdata = {'ip':'192.168.99.142', 'db':'CMAPP'}
user142 = 'cmapp'
pwd142 = '0000'
conn_DBdata = pyodbc.connect('DRIVER={SQL Server};SERVER=' + DBdata['ip'] + \
              ';DATABASE=' + DBdata['db'] + ';UID=' + user142 + ';PWD=' + pwd142)
DBdata_cr = conn_DBdata.cursor()
TableName = 'FB_AdsData'
# %% 
# 紀錄程式跑多久時間
run_time = time.time()

# 提取流水號、報告日期
def Get_SN_RD(TableName):
    get_both = """
        SELECT [Serial_Number], [Reporting_Date]
        FROM [CMAPP].[dbo].[{}]
        WHERE  [Serial_Number] = (SELECT MAX(Serial_Number) 
        FROM [CMAPP].[dbo].[{}])
        """
    print(get_both.format(TableName, TableName))
    DBdata_cr.execute(get_both.format(TableName, TableName))
    Both_SN_RD = DBdata_cr.fetchall()
    conn_DBdata.commit()
    return Both_SN_RD

# 清洗時間(Reporting_time)欄位，並更新
def Clean_both_SN_RD(uncleaned_data):
    index = 0
    list_of_data = [k for k in str(uncleaned_data).strip('[]').strip('()').split(',')]
    for i in list_of_data:
#         print(i.strip().strip('Decimal').strip('()').strip("'"), '\n')
        cleaned_data = i.strip().strip('Decimal').strip('()').strip("'")
        
        # 將清洗好的資料儲存
        if index%2 == 0:
            index += 1
            try:
                cleaned_SN = int(float(cleaned_data))
            except ValueError as e_reporting_date:
                print(e_reporting_date)
            
        elif index%2 == 1: 
            index += 1
            try:
                cleaned_RD = int(float(cleaned_data))
            except ValueError as e_reporting_date:
                print(e_reporting_date)
    return cleaned_SN, cleaned_RD

# 將Reporting_Date回溯1個月前
def RD_date_back(cleaned_RD):
    # 將str變成時間格式(datetime)，才能做計算
    reporting_date = datetime.strptime(str(cleaned_RD), '%Y%m%d')
    
    # 當原始資料內的日期 < 現在日期減一個月，代表資料需要的量是超過一個月
    if reporting_date.date() < (datetime.now().date() - relativedelta(months = 1)):
        reporting_date = reporting_date.date()
    else:
    # 當原始資料內的日期 < 現在日期減一個月，代表資料需要回溯一個月
        reporting_date = reporting_date.date() - relativedelta(months = 1)
    return reporting_date


# 增加流水號 & 廣告類別 & 廣告營運
def Expand_df(df, cleaned_SN): 
    # 第幾個 col 插入流水號(SN)、廣告分類(CA)、 
    idx_SN = 0
    idx_CA = 15
    Serial_Number = []
    # 廣告類別
    Category = 'FB'

    # 增加Serial_Number & Catergory(FB, GOOGL, AAPL)
    for order in range(len(df)):
        s_num = str(df.Reporting_Date[order]) + '000' + str(int(str(cleaned_SN)[8:]) + order + 1)
        Serial_Number.append(int(s_num))
    
    # 將資料插入
    df.insert(loc = idx_SN, column = 'Serial_Number', value = Serial_Number)
    df.insert(loc = idx_CA, column = 'Category', value = Category)
    return df

# df 空白轉換成 None
def Blank_to_None(df):
    for col in df.columns:
        df[col] = df[col].apply(lambda x: None if x == '' else x)
    return df 

# 將df的資料備份下來
def Df_to_Csv(df):
    # 將df內的Data儲存成CSV file
    df.to_csv('{}_FBAdsTest.csv'.format(datetime.now().strftime('%Y%m%d')), index = False, encoding='utf_8_sig')
    return None

# 刪除資料
def DelSQL(TableName: str, start_time, now_time):
    str_query = """
        DELETE
        FROM [CMAPP].[dbo].[{}]
        WHERE Reporting_Date BETWEEN {} AND {}
        """
    print(str_query.format(TableName, start_time, now_time))
    DBdata_cr.execute(str_query.format(TableName, start_time, now_time))
    conn_DBdata.commit()   

# 寫入資料
def InsertSQL(df, TableName):
    str_query = """
        INSERT INTO [CMAPP].[dbo].[{}]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],\
        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]\
        ,[Category])VALUES({})
        """
    # 將csv DataFrame每筆資料變成 list 型態
    insert_data = df.values.tolist()
    for i in range(len(insert_data)):
        print(str_query.format(TableName, str(insert_data[i]).strip('[]').replace('None', 'null')))      
        DBdata_cr.execute(str_query.format(TableName, str(insert_data[i]).strip('[]').replace('None', 'null')))
        conn_DBdata.commit() 

def send_email(Text):

    socket.getaddrinfo('127.0.0.1', 8080)

    MailSender = 'ai@cmoney.tw'
    MailSenderPwd = '1qaz@wsx'
    MailReceivers = ['love824671@gmail.com','sam_liao@comney.com.tw', 'cathy_want@comney.com.tw']
    MailText = Text
    MailContents = MIMEText(MailText,'Plain','utf-8')

    if 'well' in Text:
        MailContents['Subject'] = '成本自動化(完成)'
    else:
        MailContents['Subject'] = '成本自動化(失敗)'
    MailContents['From'] = 'ai@cmoney.tw'

    MailObj = smtplib.SMTP(host = 'smtp.gmail.com', port = '587')
    MailObj.ehlo()
    MailObj.starttls()
    MailObj.login(MailSender, MailSenderPwd)
    MailObj.sendmail(MailSender,MailReceivers,MailContents.as_string())
    MailObj.quit()

# %%
# FB SDKs爬蟲、資料整理、資料表格化
#  
#
def main_prog(start_time, end_time, now_time):
    # 起始值
    """
    access_token: 廣告金鑰
    ad_account_id: 廣告帳戶
    data_back: 往前爬多久的資料(幾個月)
    fields: FB_Ads行銷廣告資料
    count: 計算整體while迴圈跑幾次
    stop_flag: 當結束時間已經超過現在時間，使迴圈再跑一次，然後停止迴圈
    """
    access_token = 'EAAJqMzKi2IsBAHrHkHKYzF8Kc1PgskkXweJlxbv2qtNDrIVWdIHPXZBuclZAdFVuCE9tjZAfklwL8JxOmdhcZABjKYJRu9kqXMq3Q2kwBWmdZBjixZCCEkTzMXlrHeW9f3eJoylClpa0FqMUbecNair0MhT74eYZAJtwQxL5aoF4mejBTn2ZBAz6S4FSP6pUy2gZD'
    ad_account_id = 'act_132799196821088'
    count = 0
    stop_flag = 0
    FacebookAdsApi.init(access_token = access_token)

    # Insight API中的fields資料(控制需要的欄位資料)
    fields = [
        'spend',
        'campaign_name',
        'adset_name',
        'campaign_id',
        'ad_name',
        'actions',
        'objective',
        'action_values',  
        'conversions',
        'conversion_values',
        'impressions',
        'ctr',
        'cpm',
    ]

    # 起始資料放置位置
    Campaign_Name = list()
    Adset_Name = list()
    Ad_Name = list()
    Objective = list()
    Amount_Spent = list()
    Amount_Install = list()
    Amount_Purchase = list()
    Purchase_Conversion_Value = list()
    Amount_Subscribe = list()
    Subscribe_Conversion_Value = list()
    Reporting_Date = list()
    CPM = list()
    CTR = list()
    Impressions = list()

    # 起始時間、結束時間、現在爬蟲時間
    start_time, end_time, now_time = start_time, end_time, now_time.date()

    # 比較時間前後順序
    while True:
        # 計算迴圈跑幾次
        count += 1
        # Insight API中的fields資料(控制日期條件、資料的層級)
        # start_time和end_time需要為string(%Y-%m-%d)
        params = {
            'time_range': {
                        'since': start_time.strftime('%Y-%m-%d'),\
                        'until': end_time.strftime('%Y-%m-%d'), 
            }, 
            # level從campaign改成ad
            'level': {'ad'},
            'time_increment': '1',
            # 手動設定的歸因: 7天點擊後(和廣告預設值有落差)
            'action_attribution_windows': {'7d_click'},
        }

        # 廣告帳號獲取廣告Insights資訊
        acc_insights = AdAccount(ad_account_id).get_insights(
            fields = fields,
            params = params,
        )

        # 了解時間怎麼走
        print(start_time.strftime('%Y-%m-%d'))
        print(end_time.strftime('%Y-%m-%d'))
        
        # stop_flag = 0 代表end_time的時間已經超過現在時間(now_time)
        if stop_flag == 0:
        # 起始時間(start_time)和結束時間(end_time)，一次取一星期
            start_time = end_time + relativedelta(days = 1)
        else:
            start_time = end_time
        
        # 每次都將結束時間(end_time)，往後增加一星期
        end_time = end_time + relativedelta(weeks = 1)

        # 從廣告Inishgts資訊中，清洗、篩選資料
        for acc_insight in acc_insights:     
            campaign_name = ''
            adset_name = ''
            ad_name = ''
            amount_spent = ''
            objective = ''
            amount_subscribe = '' 
            subscribe_conversion_value = ''
            amount_install = '' 
            amount_purchase = ''    
            purchase_conversion_value = ''
            reporting_date = ''          
            cpm = ''
            ctr = ''
            impressions = ''         

            # insights/campaign_name得到 "產品包名稱"
            if 'campaign_name' in acc_insight:
                campaign_name = acc_insight['campaign_name']
                if '⛔️股市爆料同學會' in campaign_name:
                    campaign_name = campaign_name.replace('⛔️', '')

            # insights/adset_name得到 "產品名稱"
            if 'adset_name' in acc_insight:
                adset_name = acc_insight['adset_name']
                
            # insights/adset_name得到 "廣告名稱"
            if 'ad_name' in acc_insight:
                ad_name = acc_insight['ad_name']
            
            # insights/cpm得到 "每一次廣告的曝光成本"
            if 'cpm' in acc_insight:
                cpm = acc_insight['cpm']
                
            # insights/ctr得到 "廣告點擊率"
            if 'ctr' in acc_insight:
                ctr = acc_insight['ctr']

            # insights/ctr得到 "廣告觸及人數"
            if 'impressions' in acc_insight:
                impressions = acc_insight['impressions']
                
            # insights/spend得到 "總支出成本"
            if 'spend' in acc_insight:    
                amount_spent = acc_insight['spend']

            # insights/objective得到 "廣告目標"
            if 'objective' in acc_insight:
                objective = acc_insight['objective']

            # insights/date_stop得到 "報表終止日期"
            if 'date_stop' in acc_insight:
                reporting_date = datetime.strptime(acc_insight['date_stop'], '%Y-%m-%d').strftime('%Y%m%d')

            # insights/actions得到 "軟體下載數/課程購買數"
            if 'actions' in acc_insight:
                for action in acc_insight['actions']:
                    if action['action_type'] == 'mobile_app_install': 
                        amount_install = action['value']
                    if action['action_type'] == 'purchase':
                        amount_purchase = action['value']

            # insights/action_values得到 "購買轉換價值"
            if 'action_values' in acc_insight:
                for ac_values in acc_insight['action_values']:
                    if ac_values['action_type'] == 'omni_purchase':
                        purchase_conversion_value = ac_values['value']

            # insights/conversions得到 "訂閱數"
            if 'conversions' in acc_insight:
                for cv in acc_insight['conversions']:
                    if cv['action_type'] == 'subscribe_total':
                        try:
                            amount_subscribe = cv['7d_click']
                        except:
                            amount_subscribe = cv['value']

            # insights/conversion_values得到 "訂閱轉換價值"             
            if 'conversion_values' in acc_insight:
                for cv_values in acc_insight['conversion_values']:
                    if cv_values['action_type'] == 'subscribe_total':
                        try:
                            subscribe_conversion_value = cv_values['7d_click']
                        except:
                            subscribe_conversion_value = cv_values['value']

            # 將資料以List的形式儲存
            try:
                Campaign_Name.append(campaign_name)
                Adset_Name.append(adset_name)
                Ad_Name.append(ad_name)
                Objective.append(objective)
                Amount_Spent.append(amount_spent)
                Amount_Install.append(amount_install)
                Amount_Purchase.append(amount_purchase)
                Purchase_Conversion_Value.append(purchase_conversion_value)
                Amount_Subscribe.append(amount_subscribe)
                Subscribe_Conversion_Value.append(subscribe_conversion_value)
                Reporting_Date.append(reporting_date)
                CPM.append(cpm)
                CTR.append(ctr)
                Impressions.append(impressions)
                
            except UnicodeEncodeError as e:
                print(e)

# 這裡需要調整一下，想一下演算法，讓這裡能夠完美fit
            # obj_time為目標時間
            # 當目標時間 < 結束時間時，結束時間將為目標時間 
            # if obj_time < end_time:
            #     end_time = obj_time
            #     stop_flag += 1    

            if now_time < end_time:
                end_time = now_time
                stop_flag += 1     
        # 立flag
        if count > 2:
            break
            
        print('第{}次'.format(count)) 
        # 每次爬蟲完，休息60秒
        time.sleep(60)
        
        # 當成是執行4次時，暫停時間120秒
        if count%4 == 0:
            time.sleep(120)
        
        # 將資料以Dataaframe的方式儲存
        raw_data = {'Campaign_Name': Campaign_Name,
                 'Adset_Name': Adset_Name,
                 'Ad_Name': Ad_Name,
                 'Objective': Objective,
                 'Amount_Spent': Amount_Spent,
                 'Amount_Install': Amount_Install,
                 'Amount_Purchase': Amount_Purchase,
                 'Purchase_Conversion_Value': Purchase_Conversion_Value,
                 'Amount_Subscribe': Amount_Subscribe,
                 'Subscribe_Conversion_Value': Subscribe_Conversion_Value,
                 'CPM': CPM,
                 'CTR': CTR,
                 'Impressions': Impressions,
                 'Reporting_Date': Reporting_Date,}
        df = pd.DataFrame.from_dict(raw_data)
        
        # 當開始時間和結束時間相等時，立即結束程式
        if start_time == end_time:
            break
    return df

# %% 
# 獲取SN和SD
uncleaned_data = Get_SN_RD(TableName)
print(uncleaned_data)

# 將SN和SD清洗出來
cleaned_SN, cleaned_RD = Clean_both_SN_RD(uncleaned_data)
print(cleaned_SN, cleaned_RD)

# 回朔時間
new_reporting_date = RD_date_back(cleaned_RD)
print('new_reporting_date(回溯一個月的時間): ', new_reporting_date.strftime('%Y%m%d'), end ='\n')

# 開始爬蟲的時間
start_time = new_reporting_date 
print('start_time(開始爬蟲時間): ', start_time.strftime('%Y%m%d'))

# 結束爬蟲的時間
now_time = datetime.now()
print('now_time(結束爬蟲時間):  ', now_time.strftime('%Y%m%d'))
# 一次以一個星期爬蟲
end_time = new_reporting_date + relativedelta(weeks = 1)
print('end_time(給主程式跑的一星期): ', end_time.strftime('%Y%m%d'))

# 刪除資料
# DelSQL(TableName, start_time.strftime('%Y%m%d'), now_time.strftime('%Y%m%d'))

# 重新拿取SQL內的SN, RD資料
updated_uncleaned_data = Get_SN_RD(TableName)
print(updated_uncleaned_data)

# 再次清洗SN, RD資料
cleaned_SN, cleaned_RD = Clean_both_SN_RD(updated_uncleaned_data)
print(cleaned_SN, cleaned_RD)
# %%
# 抓取一個月資料，並分成一次一星期
# start_time = datetime.strptime(str(cleaned_RD), '%Y%m%d').date()
# end_time = start_time + relativedelta(weeks = 1)
# obj_time =  start_time + relativedelta(months = 1)
# print(obj_time.strftime('%Y%m%d'))

# 嘗試模組化我們的資料結構
try:
    # df = main_prog(start_time, end_time, obj_time)
    df = main_prog(start_time, end_time, now_time)
    # 將df擴增流水號和廣告種類標籤
    df = Expand_df(df, cleaned_SN)
    # 將df內的空值""，儲存成None的型態
    df = Blank_to_None(df)
    # 將df儲存成csv檔案保存
    Df_to_Csv(df)
    #將資料型態轉為字串,但實際上不轉換寫入SQL時,SQL也會自動處理
    df['Reporting_Date'] = df['Reporting_Date'].astype('str') 
    InsertSQL(df, TableName)
    Msg = '{} The program works well'.format(datetime.now().date())
    
except Exception as e:
    error_class = e.__class__.__name__ #取得錯誤類型
    detail = e.args[0] #取得詳細內容
    _, _, tb = sys.exc_info() #取得Call Stack
    lastCallStack = traceback.extract_tb(tb)[-1] #取得Call Stack的最後一筆資料
    fileName = lastCallStack[0] #取得發生的檔案名稱
    lineNum = lastCallStack[1] #取得發生的行號
    funcName = lastCallStack[2] #取得發生的函數名稱
    Msg = "File \"{}\", line {}, in {}: [{}] {}".format(fileName, lineNum, funcName, error_class, detail)
    print(Msg, '\n')

send_email(Msg)
# flag確立program完整結束
print('--- %s seconds ---' % (time.time() - run_time))
# Out:
#         SELECT [Serial_Number], [Reporting_Date]
#         FROM [CMAPP].[dbo].[FB_AdsData]
#         WHERE  [Serial_Number] = (SELECT MAX(Serial_Number)
#         FROM [CMAPP].[dbo].[FB_AdsData])
#
# [(Decimal('2021022400051359'), '20210224')]
# 2021022400051359 20210224
# new_reporting_date(回溯一個月的時間):  20210224
# start_time(開始爬蟲時間):  20210224
# now_time(結束爬蟲時間):   20210409
# end_time(給主程式跑的一星期):  20210303
#
#         SELECT [Serial_Number], [Reporting_Date]
#         FROM [CMAPP].[dbo].[FB_AdsData]
#         WHERE  [Serial_Number] = (SELECT MAX(Serial_Number)
#         FROM [CMAPP].[dbo].[FB_AdsData])
#
# [(Decimal('2021022400051359'), '20210224')]
# 2021022400051359 20210224
# c:\users\user1\appdata\local\programs\python\python38\lib\site-packages\facebook_business\utils\api_utils.py:30: UserWarning: value of level might not be compatible.  Expect level_enum;  got <class 'set'>
#   warnings.warn(message)
# c:\users\user1\appdata\local\programs\python\python38\lib\site-packages\facebook_business\utils\api_utils.py:30: UserWarning: value of action_attribution_windows might not be compatible.  Expect list<action_attribution_windows_enum>;  got <class 'set'>
#   warnings.warn(message)
# 2021-02-24
# 2021-03-03
# 第1次
# 2021-03-04
# 2021-03-10
# 第2次
# 2021-03-11
# 2021-03-17
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051360, '武財神_點燈活動', '道教興趣', '道教興趣', 'CONVERSIONS', '1080', null, '22', '122113', null, null, '126.805213', '0.857109', '8517', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051361, '武財神_點燈活動', '過去四年已購買武德宮的受眾', '過去四年已購買武德宮的類似受眾', 'CONVERSIONS', '1150', null, null, null, null, null, '148.253191', '2.539642', '7757', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051362, '武財神_APP下載_iOS_20200723', '武財神__iOS_25-65+_興趣_道教_自動版位', '上香功能影片', 'APP_INSTALLS', '1021', '65', null, null, '1', '120', '93.652541', '1.724454', '10902', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051363, '武財神_APP下載_Android_2020817_只留年訂閱', '武財神__Android_25-65+_類似受眾_年訂閱_自動版位', '求籤圖片', 'APP_INSTALLS', '114', '8', null, null, null, null, '181.818182', '4.14673', '627', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051364, '武財神_APP下載_iOS_2020921_求籤圖片', '武財神__iOS_25-65+_興趣_道教_自動版位', '求籤圖片２', 'APP_INSTALLS', '253', '8', null, null, null, null, '87.091222', '1.273666', '2905', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051365, '20200922_艾蜜莉APP_IOS_下載_軟體', '財報投資受眾_IOS (便宜價)', '單一圖片_便宜價', 'APP_INSTALLS', '670', '46', null, null, null, null, '102.446483', '1.406728', '6540', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051366, '20200922_艾蜜莉APP_Android_下載_軟體', '財報投資受眾_Android (便宜價)', '單一圖片_便宜價', 'APP_INSTALLS', '330', '34', null, null, null, null, '96.378505', '1.869159', '3424', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051367, '20200922_艾蜜莉APP_Android_下載_軟體', '基本面受眾_Android (便宜價)', '圖片_便宜價+紫色功能圖', 'APP_INSTALLS', '17', '2', null, null, null, null, '105.590062', '1.863354', '161', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051368, '武財神_APP_iOS_20201014', '道教受眾_iOS', '求籤圖片', 'APP_INSTALLS', '346', '14', null, null, '1', '120', '94.14966', '1.306122', '3675', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051369, '2020 Q4 恩如LIKE', '波段+(理&投&小)互動類似受眾+排除粉專按讚', '影片：年終精簡版', 'PAGE_LIKES', '321', null, null, null, null, null, '118.101545', '2.943341', '2718', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051370, '20201110_艾蜜莉下載_IOS_自動化廣告_軟體', 'IOS_自動化廣告', '自動化廣告', 'APP_INSTALLS', '1507', '79', null, null, null, null, '115.434699', '1.455381', '13055', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051371, '20201110_艾蜜莉下載_Android_自動化廣告_軟體', 'Android_自動化廣告', '自動化廣告', 'APP_INSTALLS', '1509', '78', null, null, null, null, '105.200781', '1.289738', '14344', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051372, '20200922_艾蜜莉APP_IOS_下載_軟體', '同學會受眾_IOS (便宜價)', '圖片_便宜價+紫色功能圖', 'APP_INSTALLS', '200', '14', null, null, null, null, '96.29273', '1.396245', '2077', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051373, '20200922_艾蜜莉APP_Android_下載_軟體', '同學會受眾_Android (便宜價)', '單一圖片_便宜價', 'APP_INSTALLS', '373', '24', null, null, null, null, '108.809802', '1.400233', '3428', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051374, '20200922_艾蜜莉APP_IOS_下載_軟體', '1%類似_艾蜜莉受眾_IOS (便宜價)', '單一圖片_便宜價', 'APP_INSTALLS', '2680', '176', null, null, '1', '390', '95.363484', '1.466036', '28103', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051375, '2020 Q4 恩如LIKE', '造訪基本面粉專(180D)+排除粉專按讚', '影片：年終精簡版', 'PAGE_LIKES', '402', null, null, null, null, null, '105.900948', '2.31823', '3796', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051376, '2020 Q4 恩如LIKE', '購買開啟安裝強棒APP者(180D)&TW2+排除粉專按讚', '影片：年終精簡版', 'PAGE_LIKES', '218', null, null, null, null, null, '191.22807', '3.333333', '1140', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051377, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW1-5%)+排除粉專按讚', '影片：年終精簡版', 'PAGE_LIKES', '242', null, null, null, null, null, '123.721881', '2.351738', '1956', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051378, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW5-6%)+排除粉專按讚 - 複本', '影片：年終精簡版', 'PAGE_LIKES', '329', null, null, null, null, null, '109.411373', '1.962088', '3007', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051379, '期貨電子盤_下載_Android - 股票受眾', '股票受眾_android_', '股票受眾_Android', 'APP_INSTALLS', '61', '4', null, null, null, null, '85.314685', '0.699301', '715', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051380, '20200922_艾蜜莉APP_IOS_下載_軟體', '1%類似_基本面受眾_IOS (便宜價)', '單一圖片_便宜價', 'APP_INSTALLS', '116', '7', null, null, null, null, '93.172691', '1.445783', '1245', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051381, '20200922_艾蜜莉APP_IOS_下載_軟體', '價值投資X艾蜜莉粉專最多職業受眾_IOS (便宜價)', '圖片_便宜價+紫色功能圖', 'APP_INSTALLS', '58', '3', null, null, null, null, '91.338583', '0.472441', '635', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051382, '丹尼爾_IOS_下載_軟體', '丹尼爾_林恩如開啟', '投信大買主流股01', 'APP_INSTALLS', '284', '17', null, null, null, null, '156.992814', '2.045329', '1809', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051383, '丹尼爾_IOS_下載_軟體', '丹尼爾_無聊詹開啟', '投信大買主流股01', 'APP_INSTALLS', '34', '2', null, null, null, null, '112.582781', '1.324503', '302', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051384, '丹尼爾_Android_下載_軟體', '丹尼爾_阿格力開啟', '投信大買主流股01', 'APP_INSTALLS', '31', '4', null, null, null, null, '159.793814', '3.092784', '194', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051385, '丹尼爾_Android_下載_軟體', '丹尼爾_同學會APP開啟', '投信大買主流股01', 'APP_INSTALLS', '266', '20', null, null, null, null, '99.924869', '1.352367', '2662', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051386, '丹尼爾_IOS_下載_軟體', '丹尼爾_阿格力開啟', '投信大買主流股01', 'APP_INSTALLS', '318', '17', null, null, null, null, '196.538937', '1.854141', '1618', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051387, '丹尼爾_IOS_下載_軟體', '同學會APP開啟', '投信大買主流股01', 'APP_INSTALLS', '977', '54', null, null, null, null, '112.544638', '1.140422', '8681', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051388, '丹尼爾_IOS_下載_軟體', '丹尼爾_籌碼K開啟', '投信大買主流股01', 'APP_INSTALLS', '335', '21', null, null, null, null, '96.960926', '1.447178', '3455', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051389, '丹尼爾_Android_下載_軟體', '丹尼爾_籌碼K開啟', '投信大買主流股01', 'APP_INSTALLS', '1798', '119', null, null, null, null, '153.478446', '1.920615', '11715', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051390, '大股東_自動化應用程式安裝_android', '大股東_自動化受眾_android', '商店頁文案圖片', 'APP_INSTALLS', '201', '21', null, null, null, null, '83.092187', '1.240182', '2419', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051391, '大股東_自動化應用程式安裝_iOS', '大股東_自動化受眾_ios', '商店頁文案圖片', 'APP_INSTALLS', '405', '35', null, null, null, null, '102.948653', '1.550585', '3934', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051392, '丹尼爾_Android_下載_軟體', '丹尼爾_理財寶互動', '投信大買主流股01', 'APP_INSTALLS', '64', '4', null, null, null, null, '65.57377', '0.819672', '976', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051393, '大股東_手動應用程式安裝_iOS', '大股東_股票興趣受眾_ios', '商店頁文案圖片', 'APP_INSTALLS', '404', '26', null, null, null, null, '80.654821', '1.17788', '5009', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051394, '大股東_手動應用程式安裝_android', '大股東_股票興趣受眾_android', '商店頁文案圖片', 'APP_INSTALLS', '201', '14', null, null, null, null, '68.530515', '0.613706', '2933', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051395, '期貨電子盤_IOS_預算手動', 'IOS_經濟日報受眾', 'IOS_經濟日報受眾_自動化廣告', 'APP_INSTALLS', '97', '3', null, null, null, null, '89.898054', '0.926784', '1079', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051396, '期貨電子盤_IOS_預算手動', 'IOS_Mobile01受眾', 'IOS_Mobile01受眾_自動化廣告', 'APP_INSTALLS', '28', null, null, null, null, null, '114.285714', '0', '245', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051397, '期貨電子盤_Android_預算手動', 'Android_經濟日報受眾', 'Android_經濟日報受眾_自動化廣告', 'APP_INSTALLS', '21', null, null, null, null, null, '100', '0.47619', '210', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051398, '期貨電子盤_Android_預算手動', 'Android_好房網受眾', 'Android_好房網受眾_自動化廣告', 'APP_INSTALLS', '20', '2', null, null, null, null, '91.743119', '1.834862', '218', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051399, '期貨電子盤_Android_預算手動', 'Android_Mobile01受眾', 'Android_Mobile01受眾_自動化廣告', 'APP_INSTALLS', '99', '1', null, null, null, null, '95.009597', '0.671785', '1042', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051400, '20210113_阿格力_下載_Android', '阿格力_自動化下載廣告_Android', '基本功能介紹', 'APP_INSTALLS', '251', '26', null, null, null, null, '87.395543', '1.566852', '2872', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051401, '20210113_阿格力_下載_IOS', '阿格力_自動化下載廣告_IOS', '基本功能介紹', 'APP_INSTALLS', '253', '20', null, null, null, null, '82.787958', '1.865183', '3056', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051402, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣', '財報複雜(圖)', 'APP_INSTALLS', '3', null, null, null, null, null, '125', '4.166667', '24', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051403, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣', '台股高檔(圖)', 'APP_INSTALLS', '11', null, null, null, null, null, '95.652174', '0', '115', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051404, '20210105阿勳APP下載_Android_軟體', 'android_外部投資興趣', '財報複雜(圖)', 'APP_INSTALLS', '35', null, null, null, null, null, '74.946467', '0.642398', '467', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051405, '20210105阿勳APP下載_Android_軟體', 'android_外部投資興趣', '台股高檔(圖)', 'APP_INSTALLS', '1206', '51', null, null, null, null, '102.272727', '1.679104', '11792', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051406, '210115_股市Podcast_下載_自動_X實驗室', '210115_股市Podcast_下載_自動_Android', '男人素材', 'APP_INSTALLS', '202', '28', null, null, null, null, '53.823608', '1.412204', '3753', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051407, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW5-6%)+排除粉專按讚 - 複本', '影片：操盤手課程影音_前半', 'PAGE_LIKES', '609', null, null, null, null, null, '115.515933', '2.408953', '5272', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051408, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW5-6%)+排除粉專按讚 - 複本', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '267', null, null, null, null, null, '132.901941', '3.434545', '2009', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051409, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW1-5%)+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '966', null, null, null, null, null, '116.694854', '2.947572', '8278', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051410, '2020 Q4 恩如LIKE', '波段+(理&投&小)互動類似受眾+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '888', null, null, null, null, null, '110.585305', '4.458281', '8030', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051411, '2020 Q4 恩如LIKE', '造訪基本面粉專(180D)+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '805', null, null, null, null, null, '105.767967', '3.521219', '7611', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051412, '2020 Q4 恩如LIKE', '購買開啟安裝強棒APP者(180D)&TW2+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '1001', null, null, null, null, null, '153.058104', '3.746177', '6540', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051413, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣 (股票or價值投資)', '台股高檔(圖)', 'APP_INSTALLS', '920', '37', null, null, null, null, '101.860053', '1.262179', '9032', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051414, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣 (股票or價值投資)', '財報複雜(圖)', 'APP_INSTALLS', '259', '15', null, null, null, null, '101.608474', '1.216163', '2549', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051415, '2021_Q1_艾蜜莉下載_IOS_自動化廣告', '20210127_艾蜜莉_IOS', '20210127_艾蜜莉下載_IOS_新舊素材', 'APP_INSTALLS', '681', '32', null, null, null, null, '90.079365', '1.402116', '7560', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051416, '2021_Q1_艾蜜莉下載_Android_自動化廣告', '20210129_艾蜜莉下載_Android_自動化廣告', '20210127_艾蜜莉下載_Android_新舊素材', 'APP_INSTALLS', '269', '22', null, null, null, null, '91.683708', '1.874574', '2934', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051417, '武財神_點燈活動 - 財神公仔無底座', '過去四年已購買武德宮的類似受眾', '過去四年已購買武德宮的類似受眾', 'CONVERSIONS', '302', null, null, null, null, null, '112.770724', '0.970874', '2678', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051418, '武財神_點燈活動 - 財神公仔無底座', '曾瀏覽武財神LP的人', '曾瀏覽武財神LP的人', 'CONVERSIONS', '52', null, null, null, null, null, '327.044025', '0.628931', '159', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051419, '武財神_點燈活動 - 財神公仔無底座', '過去4年購買武德宮的名單', '過去四年曾購買武德宮', 'CONVERSIONS', '901', null, null, null, null, null, '267.121257', '3.379781', '3373', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051420, '期貨電子盤_下載_Android - 興趣期貨受眾', '期貨受眾_Android', '期貨受眾_Android', 'APP_INSTALLS', '33', null, null, null, null, null, '89.430894', '0.542005', '369', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051421, '武財神_LP導購買_20220201', '武財神_導購買_LP - 道教興趣', '武財神 LandingPage廣告-無公仔', 'CONVERSIONS', '109', null, null, null, null, null, '152.661064', '0.70028', '714', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051422, '武財神_LP導購買_20220201', '武財神_導購買_LP - 道教興趣', '武財神 LandingPage廣告-財運加持組合包', 'CONVERSIONS', '110', null, '11', '85205', null, null, '154.494382', '0.140449', '712', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051423, '武財神_點燈活動 - 財神公仔無底座', '過去四年已購買武德宮的類似受眾', '武財神 LandingPage廣告-疫情肆虐不害怕 - 複本', 'CONVERSIONS', '353', '2', null, null, '1', '120', '191.43167', '1.789588', '1844', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051424, '武財神_點燈活動 - 財神公仔無底座', '曾瀏覽武財神LP的人', '武財神 LandingPage廣告-疫情肆虐不害怕 - 複本', 'CONVERSIONS', '5', null, null, null, null, null, '104.166667', '4.166667', '48', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051425, '武財神_點燈活動 - 財神公仔無底座', '過去四年已購買武德宮的類似受眾', '武財神 LandingPage廣告-牛年加薪就靠祂 - 複本', 'CONVERSIONS', '160', null, null, null, null, null, '232.896652', '1.164483', '687', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051426, '武財神_點燈活動 - 財神公仔無底座', '曾瀏覽武財神LP的人', '武財神 LandingPage廣告-牛年加薪就靠祂 - 複本', 'CONVERSIONS', '15', null, null, null, null, null, '272.727273', '0', '55', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051427, '武財神_點燈活動 - 財神公仔無底座', '過去四年已購買武德宮的類似受眾', '武財神 LandingPage廣告-加薪升官財運包 - 複本', 'CONVERSIONS', '85', null, null, null, null, null, '229.110512', '0.808625', '371', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051428, '武財神_點燈活動 - 財神公仔無底座', '過去四年已購買武德宮的類似受眾', '武財神 LandingPage廣告-財運加持組合包 - 複本', 'CONVERSIONS', '332', null, null, null, null, null, '194.950088', '2.113917', '1703', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051429, '武財神_點燈活動 - 財神公仔無底座', '曾瀏覽武財神LP的人', '武財神 LandingPage廣告-財運加持組合包 - 複本', 'CONVERSIONS', '26', null, null, null, null, null, '376.811594', '0', '69', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051430, '期貨電子盤_IOS_預算手動', 'IOS_CMoney理財寶受眾', 'IOS_CMoney理財寶受眾_自動化廣告', 'APP_INSTALLS', '30', null, null, null, null, null, '97.71987', '0.651466', '307', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051431, '期貨電子盤_IOS_預算手動', 'IOS_理財周刊受眾', 'IOS_理財周刊受眾_自動化廣告', 'APP_INSTALLS', '100', '2', null, null, null, null, '86.580087', '0.606061', '1155', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051432, '期貨電子盤_IOS_預算手動', 'IOS_今周刊受眾', 'IOS_今周刊受眾_自動化廣告', 'APP_INSTALLS', '26', '2', null, null, null, null, '94.202899', '1.086957', '276', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051433, '期貨電子盤_IOS_預算手動', 'IOS_股票財經日報受眾', 'IOS_股票財經日報受眾_自動化廣告', 'APP_INSTALLS', '101', null, null, null, null, null, '82.314588', '0.0815', '1227', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051434, '期貨電子盤_IOS_預算手動', 'IOS_Technews科技新報受眾', 'IOS_Technews科技新報受眾_自動化廣告', 'APP_INSTALLS', '29', '1', null, null, null, null, '83.815029', '0.867052', '346', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051435, '武財神_LP導購買_20220201', '武財神_導購買_LP - 複本 - 複本', '武財神 LandingPage廣告-加薪升官財運包', 'CONVERSIONS', '240', null, '3', '1047', null, null, '361.445783', '1.807229', '664', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051436, '武財神_LP導購買_20220201', '武財神_導購買_LP - 複本 - 複本', '武財神 LandingPage廣告-財運加持組合包', 'CONVERSIONS', '37', null, '1', '349', null, null, '268.115942', '3.623188', '138', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051437, '武財神_LP導購買_20220201', '武財神_導購買_LP - 複本 - 複本', '武財神 LandingPage廣告-牛年加薪就靠祂', 'CONVERSIONS', '286', null, '2', '3776', null, null, '311.207835', '1.632209', '919', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051438, '武財神_LP導購買_20220201', '武財神_導購買_LP - 複本 - 複本', '武財神 LandingPage廣告-疫情肆虐不害怕', 'CONVERSIONS', '1170', '2', '13', '41355', null, null, '260.869565', '2.363434', '4485', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051439, '期貨電子盤_Android_預算手動', 'Android_Technews科技新報受眾', 'Android_Technews科技新報受眾_自動化廣告', 'APP_INSTALLS', '100', '3', null, null, null, null, '80.256822', '0.642055', '1246', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051440, '2021_Q1_陳重銘_銷售($349)_購買(新客)', '20210222_陳重銘_購買(新客)_素材混合', '20210222_陳重銘_轉換(新客)_APP圖', 'CONVERSIONS', '23', null, null, null, null, null, '47.520661', '8.677686', '484', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051441, '2021_Q1_陳重銘_銷售($349)_購買(新客)', '20210222_陳重銘_購買(新客)_素材混合', '20210222_陳重銘_轉換(新客)_人物圖', 'CONVERSIONS', '28', null, null, null, null, null, '56.565657', '11.313131', '495', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051442, '2021_Q1_陳重銘_銷售($349)_購買(新客)', '20210222_陳重銘_購買(新客)_素材混合', '20210222_陳重銘_轉換(新客)_影片', 'CONVERSIONS', '94', null, null, null, null, null, '66.525124', '8.492569', '1413', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051443, '2021_Q1_陳重銘_銷售($349)_購買(舊客)', '20210222_陳重銘_購買(舊客)_類似1%陳重銘購買', '20210222_陳重銘_轉換_類似1%陳重銘購買', 'CONVERSIONS', '57', null, null, null, null, null, '96.446701', '12.521151', '591', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051444, '2021_Q1_陳重銘_銷售($349)_購買(舊客)', '20210222_陳重銘_購買(舊客)_類似2%/3%陳重銘購買', '20210222_陳重銘_類似2%/3%陳重銘購買', 'CONVERSIONS', '19', null, null, null, null, null, '65.743945', '6.920415', '289', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051445, '2021_Q1_陳重銘_銷售($349)_購買(舊客)', '20210222_陳重銘_購買(舊客)_APP/互動', '20210222_陳重銘_轉換(舊客)_APP/互動', 'CONVERSIONS', '39', null, null, null, null, null, '104.557641', '14.745308', '373', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051446, '武財神_LP導購買_20220201', '武財神_導購買_LP - 道教興趣', '武財神 LandingPage廣告-武財神神像', 'CONVERSIONS', '1944', '1', '13', '27587', '1', '120', '208.762887', '2.727663', '9312', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051447, '20210105阿勳APP下載_Android_軟體', 'android_Lookalike_阿勳貼文廣告有互動', '台股高檔(圖)', 'APP_INSTALLS', '444', '27', null, null, null, null, '105.088757', '1.704142', '4225', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051448, '20210105阿勳APP下載_Android_軟體', 'android_Lookalike_阿勳貼文廣告有互動', '介紹APP(影)', 'APP_INSTALLS', '44', '2', null, null, null, null, '133.333333', '0.909091', '330', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051449, '20210105阿勳APP下載_iOS_軟體', 'IOS_Lookalike_阿勳貼文廣告有互動', '台股高檔(圖)', 'APP_INSTALLS', '325', '7', null, null, null, null, '116.529222', '0.896379', '2789', '20210224', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021022400051450, '20210105阿勳APP下載_iOS_軟體', 'IOS_Lookalike_阿勳貼文廣告有互動', '介紹APP(影)', 'APP_INSTALLS', '53', '1', null, null, null, null, '109.730849', '0.621118', '483', '20210224', 'FB')
#
#
# ...
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052249, '大股東_自動化應用程式安裝_iOS', '大股東_自動化受眾_ios', '商店頁文案圖片', 'APP_INSTALLS', '398', '34', null, null, null, null, '110.617009', '1.473041', '3598', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052250, '大股東_手動應用程式安裝_iOS', '大股東_股票興趣受眾_ios', '商店頁文案圖片', 'APP_INSTALLS', '394', '26', null, null, null, null, '86.346702', '1.205347', '4563', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052251, '大股東_手動應用程式安裝_android', '大股東_股票興趣受眾_android', '商店頁文案圖片', 'APP_INSTALLS', '199', '14', null, null, null, null, '77.401789', '1.478024', '2571', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052252, '20210113_阿格力_下載_Android', '阿格力_自動化下載廣告_Android', '基本功能介紹', 'APP_INSTALLS', '251', '23', null, null, null, null, '83.890374', '1.537433', '2992', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052253, '20210113_阿格力_下載_IOS', '阿格力_自動化下載廣告_IOS', '基本功能介紹', 'APP_INSTALLS', '249', '24', null, null, null, null, '85.68479', '1.514109', '2906', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052254, '20210105阿勳APP下載_Android_軟體', 'android_外部投資興趣', '台股高檔(圖)', 'APP_INSTALLS', '603', '20', null, null, null, null, '110.338518', '1.610247', '5465', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052255, '210115_股市Podcast_下載_自動_X實驗室', '210115_股市Podcast_下載_自動_Android', '男人素材', 'APP_INSTALLS', '89', '11', null, null, null, null, '75.615973', '1.784197', '1177', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052256, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW5-6%)+排除粉專按讚 - 複本', '影片：操盤手課程影音_前半', 'PAGE_LIKES', '1051', null, null, null, null, null, '152.0764', '2.575604', '6911', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052257, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW5-6%)+排除粉專按讚 - 複本', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '131', null, null, null, null, null, '181.440443', '3.462604', '722', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052258, '2020 Q4 恩如LIKE', '恩如類似受眾(@TW1-5%)+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '928', null, null, null, null, null, '169.528681', '3.069054', '5474', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052259, '2020 Q4 恩如LIKE', '波段+(理&投&小)互動類似受眾+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '974', null, null, null, null, null, '155.120242', '4.252269', '6279', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052260, '2020 Q4 恩如LIKE', '造訪基本面粉專(180D)+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '870', null, null, null, null, null, '138.4028', '2.958956', '6286', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052261, '2020 Q4 恩如LIKE', '購買開啟安裝強棒APP者(180D)&TW2+排除粉專按讚', '影片：操盤手課程影音_後半', 'PAGE_LIKES', '996', null, null, null, null, null, '209.860936', '3.876949', '4746', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052262, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣 (股票or價值投資)', '台股高檔(圖)', 'APP_INSTALLS', '391', '11', null, null, null, null, '108.280255', '0.996954', '3611', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052263, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣 (股票or價值投資)', '財報複雜(圖)', 'APP_INSTALLS', '287', '12', null, null, null, null, '119.334719', '0.956341', '2405', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052264, '2021_Q1_艾蜜莉下載_IOS_自動化廣告', '20210127_艾蜜莉_IOS', '20210127_艾蜜莉下載_IOS_新舊素材', 'APP_INSTALLS', '348', '16', null, null, null, null, '112.621359', '1.84466', '3090', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052265, '2021_Q1_艾蜜莉下載_Android_自動化廣告', '20210129_艾蜜莉下載_Android_自動化廣告', '20210127_艾蜜莉下載_Android_新舊素材', 'APP_INSTALLS', '253', '20', null, null, null, null, '83.664021', '2.579365', '3024', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052266, '期貨電子盤_下載_Android - 興趣期貨受眾', '期貨受眾_Android', '期貨受眾_Android', 'APP_INSTALLS', '203', '10', null, null, null, null, '50.838968', '0.626096', '3993', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052267, '20210105阿勳APP下載_Android_軟體', 'android_Lookalike_阿勳貼文廣告有互動', '台股高檔(圖)', 'APP_INSTALLS', '268', '14', null, null, null, null, '103.195995', '0.847131', '2597', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052268, '20210105阿勳APP下載_Android_軟體', 'android_Lookalike_阿勳貼文廣告有互動', '介紹APP(影)', 'APP_INSTALLS', '14', null, null, null, null, null, '100.719424', '0.719424', '139', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052269, '20210105阿勳APP下載_iOS_軟體', 'IOS_Lookalike_阿勳貼文廣告有互動', '台股高檔(圖)', 'APP_INSTALLS', '42', '2', null, null, null, null, '122.807018', '1.169591', '342', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052270, '20210105阿勳APP下載_iOS_軟體', 'IOS_Lookalike_阿勳貼文廣告有互動', '介紹APP(影)', 'APP_INSTALLS', '4', null, null, null, null, null, '125', '0', '32', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052271, '20210105阿勳APP下載_Android_軟體', 'android_外部投資興趣', '台股高檔(新圖)', 'APP_INSTALLS', '888', '45', null, null, null, null, '111.473763', '1.129802', '7966', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052272, '20210105阿勳APP下載_iOS_軟體', 'IOS_外部投資興趣 (股票or價值投資)', '台股高檔(新圖)', 'APP_INSTALLS', '1476', '54', null, null, null, null, '119.960988', '0.926528', '12304', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052273, '期貨電子盤_IOS_預算手動', 'IOS_綜合受眾', 'IOS_綜合受眾_自動化廣告', 'APP_INSTALLS', '32', '1', null, null, null, null, '62.378168', '0.974659', '513', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052274, '武財神_APP下載_20210305_擲筊廣告', '武財神_Android_道教興趣', '擲筊圖片(無神)', 'APP_INSTALLS', '986', '86', null, null, null, null, '101.117834', '2.892011', '9751', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052275, '武財神_APP下載_20210305_擲筊廣告', '武財神_Android_道教興趣', '擲筊圖片(有神)', 'APP_INSTALLS', '0', null, null, null, null, null, '0', '6.25', '16', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052276, '武財神_APP下載_20210305_擲筊廣告', '武財神_IOS_道教興趣', '擲筊圖片(有神)', 'APP_INSTALLS', '0', null, null, null, null, null, '0', '0', '3', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052277, '武財神_APP下載_20210305_擲筊廣告', '武財神_IOS_道教興趣', '擲筊圖片(無神)', 'APP_INSTALLS', '7', '2', null, null, null, null, '84.337349', '3.614458', '83', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052278, '武財神_APP下載_Android_20210310_補財庫', '武財神_APP下載_25-65+_興趣道教_Android_補財庫', '補財庫圖片', 'APP_INSTALLS', '116', '17', null, null, null, null, '86.891386', '2.172285', '1335', '20210310', 'FB')
#
#
#         INSERT INTO [CMAPP].[dbo].[FB_AdsData]([Serial_Number],[Campaign_Name],[Adset_Name],[Ad_Name],[Objective],[Amount_Spent],[Amount_Install],        [Amount_Purchase],[Purchase_Conversion_Value],[Amount_Subscribe],[Subscribe_Conversion_Value],[CPM],[CTR],[Impressions],[Reporting_Date]        ,[Category])VALUES(2021031000052279, '武財神_APP下載_IOS_20210310_補財庫', '武財神_APP下載_25-65+_興趣道教_IOS_補財庫', '補財庫圖片', 'APP_INSTALLS', '116', '2', null, null, null, null, '83.094556', '2.292264', '1396', '20210310', 'FB')
#
# --- 198.64814066886902 seconds ---
