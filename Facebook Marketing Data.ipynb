# %% [markdown]
# Objective
# ===
#
# ## Reference:
# [Fb Admanager - Fb Developer](https://business.facebook.com/adsmanager/manage)
#
# [Fb Insight API - Fb Developer](https://developers.facebook.com/docs/marketing-api/insights/parameters/v8.0)
#
# [Fb Python SDK - Fb Developer](https://github.com/facebook/facebook-python-business-sdk?fbclid=IwAR1IF-dAmqaYunRjw8EgQLXQlbezsrWzzpPTMZXGTkoCFtja0YbP11r4Av4)
#
# [Python strgtime() function](https://www.programiz.com/python-programming/datetime/strftime)
#
# ### Basic Coding problem
# [if, elif, else concept](https://www.programiz.com/python-programming/if-elif-else)
#
# [Newline(\n) in CSV file](https://stackoverflow.com/questions/43733205/write-newline-to-csv-in-python)
#
# ### Jupyter lab Path Problem
# [PermissionError: [Errno 13] Permission denied](https://stackoverflow.com/questions/36434764/permissionerror-errno-13-permission-denied/36469464)

# %% [markdown]
# # 20201102 Sample(不能動) V-1

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# Fields = 讀取的欄位清單(Column names)
fields = [
    'name',
    'objective',
    'id',
]

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

# 紀錄有幾個
count = 0
A = AdAccount(ad_account_id).get_campaigns(fields)
for a in A:
    if count >= 10:
        break
    count += 1
    print('這是第%d個' % count)
    print(a['name'], end = '\n\n')

# params = 要求參數的對應
params = {
  'effective_status': ['ACTIVE', 'PAUSED'],
}

# print(AdAccount(ad_account_id).get_campaigns(

#     for field in fileds:
#         fields = fields,
#         params = params,
# ))

# %% [markdown]
# ## 20201102 調動版(fields, campaign)

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# fields_campaign = 讀取的欄位清單(Column names)
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'effective_status',
    'configured_status',
    'start_time',
    'bid_strategy',
    'adlabels', 
    'configured_status', 
    'adlabels', 
    'buying_type', 
    'is_completed', 
    'promoted_object', 
    'spend_cap', 
    'start_time', 
    'stop_time', 
    'updated_time',
]

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

# 紀錄有幾個
count = 0
A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
# print(A)

for a in A:


    if count >= 10:
        break
    count += 1
    print('這是第%d個' % count)
    print(a['name'])
    print(a, end = '\n\n')

# %% [markdown]
# ## 20201102 AdAccount(V-1)
# 失敗無法抓取
# 直接換成Adset試試看

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.adaccountuser import AdAccountUser

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# fields_campaign = 讀取的欄位清單(Column names)
fields_adaccount = [
    'BidInfo', 
    'account_id', 
    'adlabels', 
    'adset_schedule', 
    'bid_amount', 
    'bid_info', 
    'billing_event', 
    'budget_remaining', 
    'campaign_id', 
    'configured_status', 
    'created_time', 
    'creative_sequence', 
    'daily_budget', 
    'effective_status', 
    'end_time', 
    'id', 
    'is_autobid', 
    'lifetime_budget', 
    'lifetime_imps', 
    'name', 
    'optimization_goal', 
    'pacing_type', 
    'product_ad_behavior', 
    'promoted_object', 
    'rf_prediction_id', 
    'rtb_flag', 
    'start_time', 
    'targeting', 
    'updated_time',
]

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

# 紀錄有幾個
count = 0
me = AdAccountUser(fbid='me')
A = me.get_ad_accounts(fields_adaccount)
# A = AdAccount(ad_account_id).get_ad_accounts(fields_adaccount)
# print(A)

for a in A:
    if count >= 10:
        break
    count += 1
    print('這是第%d個' % count)
    print(a['name'])
    print(a, end = '\n\n')

    
    
# # 以下都還沒有動，現在正要做的是
# A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
# for a in A:
#     print('Campaign_name: ', a['name'])
#     print(a['adlabels'])
#     print(a['configured_status'])
#     print(a['effective_status'])
#     # prevent the program broken
#     if a['configured_status'] != 'Active':
#         continue
#     if count >= 10:
#         break
#     count += 1

    
#     try:
#         # 如果在Campaign內的bid_strategy欄位是KeyError的話，則重新跑回圈
#         # if a['bid_strategy'] == 'KeyError':
#         #     continue
        
#         # 將campaign內的所有adset找出來，並
#         campaign = Campaign(a['id'])
#         adsets = campaign.get_ad_sets(fields_adset)
#         for adset in adsets:
#             print('adset: ' + adset['name'] + \
#                 '\n' + 'ID: ' + adset['id'] + \
#                 '\n' + 'bid_amount: ' + str(adset['bid_amount']), end = '\n\n')
#         print(adsets)

# %% [markdown]
# ---

# %% [markdown]
# ## 20201101測試版(利用Campaign的ID，來抓取內部的Adset)

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)

# https://developers.facebook.com/docs/marketing-api/reference/sdks/python/campaign/v8.0
# Fields_campaign = 讀取的欄位清單(Column names)
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'effective_status',
    'configured_status',
    'start_time',
    'bid_strategy',
#     'adlabels', 
    'configured_status', 
    # effective_status, id, is_completed, name, buying_type,
    # objective, promoted_object, spend_cap, 
]

# https://developers.facebook.com/docs/marketing-api/reference/sdks/python/ad-set/v8.0
# Fields_adset = 讀取的欄位清單(Column names)
fields_adset = [
    'name',
    'bid_amount',
    'campaign_id',
]

# params = 要求參數的對應
params = {
  'effective_status': ['ACTIVE', 'PAUSED'],
}

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

campaign_hundred = []
# 紀錄有幾個
count = 0
A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
for a in A:
    print('Campaign_name: ', a['name'])
#     print(a['adlabels'])
    print(a['configured_status'])
#     print(a['effective_status'])

    # prevent the program broken
#     if a['configured_status'] != 'Active':
#         continue

    if count >= 10:
        break
    count += 1

    
    try:
        # 如果在Campaign內的bid_strategy欄位是KeyError的話，則重新跑回圈
        # if a['bid_strategy'] == 'KeyError':
        #     continue
        
        # 將campaign內的所有adset找出來，並
        campaign = Campaign(a['id'])
        adsets = campaign.get_ad_sets(fields_adset)
        for adset in adsets:
            print('adset: ' + adset['name'] + \
                '\n' + 'ID: ' + adset['id'] + \
                '\n' + 'bid_amount: ' + str(adset['bid_amount']), end = '\n\n')
        print(adsets)
        

        # campaign_hundred.append({
        #     'Campaign_name': a['name']
        # })

        # print('這是第%d個' % count)
        # print('Campaign name: ' + a['name'] + \
        #     '\n' + 'Campaign_id: ' + a['id'] + \
        #     '\n' + 'Objective: ' + a['objective'] + \
        #     '\n' + 'Effective status: ' + a['effective_status'], end = '\n')
        # print('Bid_strategy: '+ a['bid_strategy'], end = '\n\n')

    except KeyError as e:
        count -= 1 
        print('上面Try-loop內的根本找不到資料')
        # print('錯誤: ', e) 
    
# print(campaign_hundred)

# %% [markdown]
# ---

# %% [markdown]
# ## 20201103 Account get insights(測試)

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.adobjects.adset import AdSet
from facebook_business.api import FacebookAdsApi
from facebookads.adobjects.adsinsights import AdsInsights

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


account = AdAccount(ad_account_id)
campaign
insights = account.get_insights(fields=[
    AdsInsights.Field.campaign_id,
    AdsInsights.Field.unique_clicks,
    AdsInsights.Field.impressions,
    AdsInsights.Field.campaign_name, 
    AdsInsights.Field.spend,
    AdsInsights.Field.adset_id,
    AdsInsights.Field.campaign_id,
    AdsInsights.Field.campaign_name, 
    AdsInsights.Field.adset_name,

], params={
    'date_preset': 'last_30d',
})

print(insights)

# %% [markdown]
# ## 20201103 用來抓Campaign的insights資料(v-1)-今日最後一版

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.adobjects.adset import AdSet
from facebook_business.api import FacebookAdsApi

# access_token = '<ACCESS_TOKEN>'
# app_secret = '<APP_SECRET>'
# app_id = '<APP_ID>'
# ad_account_id = '<AD_ACCOUNT_ID>'

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# fields_campaign = 讀取的欄位清單(Column names)
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'effective_status',
    'configured_status',
    'start_time',
#     'bid_strategy',
    'adlabels', 
    'configured_status', 
    'adlabels', 
#     'buying_type', 
    'is_completed', 
    'promoted_object', 
    'spend_cap', 
    'start_time', 
    'stop_time', 
    'updated_time',
]

para_campaign = {
    'time_range': {
        'since': '2020-10-1',
        'until': '2020-11-1',
    }
}

# fields_campaign = 讀取的欄位清單(Column names)
fields_adset = [
#     'BidInfo', 
    'account_id', 
#     'adlabels', 
#     'adset_schedule', 
#     'bid_amount', 
#     'bid_info', 
#     'billing_event', 
#     'budget_remaining', 
#     'campaign_id', 
#     'configured_status', 
#     'created_time', 
#     'creative_sequence', 
#     'daily_budget', 
#     'effective_status', 
#     'end_time', 
#     'id', 
#     'is_autobid', 
#     'lifetime_budget', 
#     'lifetime_imps', 
    'name', 
#     'optimization_goal', 
#     'pacing_type', 
#     'product_ad_behavior', 
#     'promoted_object', 
#     'rf_prediction_id', 
#     'rtb_flag', 
#     'start_time', 
#     'targeting', 
#     'updated_time',
]

fields_insights = [
    'spend',
    'campaign_name',
    'conversion_values',
    'conversions',
    'cost_per_conversion',
]

para_insights = {
    'date_preset': 'last_30d',
}

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

count = 0
count_b = 0
# Campaign
A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
for a in A:
    if count >= 10:
        break
    count += 1
    
#     if count < 4: 
#         print(a['id'])
#         print(a['name'], end = '\n\n')

    # Adset需要從Campaign中拿ID
#     B = Campaign(a['id']).get_ad_sets(fields_adset)

#     if count == 5:
    try:
        # Try to find the Campaign insights "Spend"
        campaign = Campaign(a['id'])
        campaign_insights = campaign.get_insights(fields_insights, para_insights)

        # 如果Inisghts是 None，可能是Campaign內部根本沒有inisght
        if len(campaign_insights) < 1:
#             adsets = AdAccount(ad_account_id).get_ad_sets(fields_adset)
            campaign = Campaign(a['id'])
            adsets = campaign.get_ad_sets(fields_adset)
        
            print('這是第%d個' % count)
            print(a['name'])
            print(a, end = '\n')

            # adset的部分
            for b in adsets:
                count_b += 1
                if count_b >= 5:
                    break

                print(b['name'])
                print(b, end = '\n\n')

        # 如果有insights則
        else:
        

            # 從Account裡面Get到全部的Adset，但實際上要Get是不同的"Campaign下面的Adset"
            # 來做區分，而不是"所有的"
#             adsets = AdAccount(ad_account_id).get_ad_sets(fields_adset)
            campaign = Campaign(a['id'])
            adsets = campaign.get_ad_sets(fields_adset)
        
            print('這是第%d個' % count)
#             print(len(campaign_insights))
            print(campaign_insights[0]['campaign_name'])
            print('insights: ', campaign_insights, end = '\n\n')
            
            # 這裡是Print出 Campagin的名字
            print(a['name'])
            print(a, end = '\n')

            #---------------------------------------------------------
            # 列印adset的部分
            for b in adsets:
#                 count_b += 1
#                 if count_b >= 5:
#                     break

                print(b['name'])
                print(b, end = '\n\n')

    except AttributeError as e:
        print(e)

# %% [markdown]
# ## Insights 篩檢版

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.adobjects.adset import AdSet
from facebook_business.api import FacebookAdsApi

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# fields_campaign = 讀取的欄位清單(Column names)----------------------------------
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'start_time',
    'stop_time', 
    'updated_time',
    'effective_status',
]

para_campaign = {
    'time_range': {
        'since': '2020-10-1',
        'until': '2020-11-1',
    }
}
# ---------------------------------------------------------------------------


# fields_campaign = 讀取的欄位清單(Column names)----------------------------------

fields_adset = [
    'name', 
]
# ---------------------------------------------------------------------------


## insights API fields&para---------------------------------------------------
fields_insights = [
    'spend',
    'campaign_name',
    'conversion_values',
    'full_view_reach',
    'cost_per_conversion',
]

para_insights = {
    'date_preset': 'last_7d',
}
# ---------------------------------------------------------------------------

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

# Count if inoder to avoid  rate limit
count = 0
# Campaign's data from the Account
A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
for a in A:
    if count >= 5:
        break
    count += 1
    
    # Adset需要從Campaign中拿ID
#     B = Campaign(a['id']).get_ad_sets(fields_adset)

    try:
        # Try to find the Campaign insights "Spend"
        campaign = Campaign(a['id'])
        campaign_insights = campaign.get_insights(fields_insights, para_insights)

        # 如果Inisghts是 None，可能是Campaign內部根本沒有inisght
        if len(campaign_insights) < 1:
            adsets = AdAccount(ad_account_id).get_ad_sets(fields_adset)
            print('這是第%d個' % count)
            print(a['name'])
            print(a, end = '\n')

            # adset的部分
            for b in adsets:
                count_b += 1
                if count_b >= 5:
                    break

                print(b['name'])
                print(b, end = '\n\n')

        # 如果有insights則
        else:
        
            # 從Account裡面Get到全部的Adset，但實際上要Get是不同的"Campaign下面的Adset"
            # 來做區分，而不是"所有的"
            adsets = AdAccount(ad_account_id).get_ad_sets(fields_adset)

            print('這是第%d個' % count)
#             print(len(campaign_insights))
            print(campaign_insights[0]['campaign_name'])
            print(campaign_insights, end = '\n\n')
            
            # 這裡是Print出 Campagin的名字
            print(a['name'])
            print(a, end = '\n')

            #---------------------------------------------------------
            count_b = 0
            # 列印adset的部分
            for b in adsets:
                count_b += 1
                if count_b >= 5:
                    break
                print(b['name'] + '\n' + str(b), end = '\n\n')
                
#                 print(b, end = '\n\n')
    except AttributeError as e:
        print(e)

# %% [markdown]
# ## 20201106 最終資料版

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.adobjects.adset import AdSet
from facebook_business.api import FacebookAdsApi

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# fields_campaign = 讀取的欄位清單(Column names)----------------------------------
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'start_time',
    'stop_time', 
    'updated_time',
    'effective_status',
]

para_campaign = {
    'time_range': {
        'since': '2020-10-1',
        'until': '2020-11-1',
    }
}
# ---------------------------------------------------------------------------

## insights API fields&para---------------------------------------------------
fields_insights = [
    'spend',
    'campaign_name',
    'conversion_values',
    'full_view_reach',
    'actions',
]

para_insights = {
    'date_preset': 'last_7d',
    'level': 'campaign',
#     '',
}
# ---------------------------------------------------------------------------

# print(AdAccount(ad_account_id).get_campaigns(fields), end = '\t\t')

# Count if inoder to avoid  rate limit
count = 0
# Campaign's data from the Account
A = AdAccount(ad_account_id).get_campaigns(fields_campaign)
for a in A:
    if count >= 5:
        break
    count += 1
    print(a['id'])
        
    try:
        # Try to find the Campaign insights "Spend"
        campaign = Campaign(a['id'])
        campaign_insights = campaign.get_insights(fields_insights, para_insights)

        # 如果Inisghts是 None，可能是Campaign內部根本沒有inisght
        if len(campaign_insights) < 1:
            print('這是第%d個' % count)
            print(a['name'])
            print(a, end = '\n')


        # 如果有insights則
        else:
            keys = []
            values = []
            for key, value in campaign_insights[0].items():
                if 'mobile_app_install' in value:
                    keys = key
                    values = value
                    
            print('這是第%d個' % count)
            print(campaign_insights[0]['campaign_name'])
            print('mobilie app install: ', values)
            print(campaign_insights[0], end = '\n\n')
            
            # 這裡是Print出 Campagin的名字
            print(a['name'])
            print(a, end = '\n')

    except AttributeError as e:
        print(e)

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# fields_campaign = 讀取的欄位清單(Column names)----------------------------------
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'start_time',
    'stop_time', 
    'updated_time',
#     'effective_status',
]

para_campaign = {
    'time_range': {
        'since': '2020-10-20',
        'until': '2020-11-1',
    }
}

## insights API fields&para---------------------------------------------------
fields_insights = [
    'spend',
    'campaign_name',
    'conversion_values',
    'full_view_reach',
    'actions',
]

para_insights = {
    'date_preset': 'last_7d',
    'time_range': {'since': '2020-10-20', 'until': '2020-11-1'},
    'level': 'campaign',
}
# ---------------------------------------------------------------------------
# Count if inoder to avoid  rate limit
count = 0
# Campaign's data from the Account
A = AdAccount(ad_account_id).get_campaigns(fields_campaign, para_campaign)
for a in A:
    
    if count >= 30:
        break
    count += 1
        
    try:
        # Try to find the Campaign insights "Spend"
        campaign = Campaign(a['id'])
        campaign_insights = campaign.get_insights(fields_insights, para_insights)

        # 如果Inisghts是 None，可能是Campaign內部根本沒有inisght
        if len(campaign_insights) < 1:
            print('這是第%d個' % count)
            print(a['name'])
            print('不確定的轉換值 or 沒有設定轉換值')
            print(a, end = '\n')
            

        else:
            print('這是第%d個' % count)
            print(a['name'])

            count_install = 0
            count_purch = 0
            count_subs = 0
            
            try:
                for i in range(len(campaign_insights[0]['actions'])):
                    if campaign_insights[0]['actions'][i]['action_type'] == 'mobile_app_install': 
                        count_install = campaign_insights[0]['actions'][i]['value']
                        print('手機軟體下載數量: ', count_install)

                    elif campaign_insights[0]['actions'][i]['action_type'] == 'purchase':
                        count_purch = campaign_insights[0]['actions'][i]['value']
                        print('購買數量: ', count_purch)

                    elif campaign_insights[0]['actions'][i]['action_type'] == 'subscription': 
                        count_subs = campaign_insights[0]['actions'][i]['value']
                        print('訂閱數量: ', count_subs)
                # 將
                print(a, end = '\n')

            except KeyError as e:
                print(e)
                continue

    except AttributeError as e:
        print(e)
# Out:
# D:\Anaconda_JupyterNotebook\lib\site-packages\facebook_business\utils\api_utils.py:30: UserWarning: campaigns does not allow field ad_setstart_time
#   warnings.warn(message)
# 這是第1個
# 陳重銘_購買_雙十一活動
# 不確定的轉換值 or 沒有設定轉換值
# <Campaign> {
#     "id": "6221721491607",
#     "name": "\u9673\u91cd\u9298_\u8cfc\u8cb7_\u96d9\u5341\u4e00\u6d3b\u52d5",
#     "objective": "CONVERSIONS",
#     "stop_time": "2020-11-11T23:59:00+0800",
#     "updated_time": "2020-11-09T14:34:08+0800"
# }
# 這是第2個
# 阿勳雙11銷售轉換
# 不確定的轉換值 or 沒有設定轉換值
# <Campaign> {
#     "id": "6221633973807",
#     "name": "\u963f\u52f3\u96d911\u92b7\u552e\u8f49\u63db",
#     "objective": "CONVERSIONS",
#     "updated_time": "2020-11-08T14:48:07+0800"
# }
# 這是第3個
# 2020Q4林恩如_實戰班講座_轉換
# 不確定的轉換值 or 沒有設定轉換值
# <Campaign> {
#     "id": "6221446151607",
#     "name": "2020Q4\u6797\u6069\u5982_\u5be6\u6230\u73ed\u8b1b\u5ea7_\u8f49\u63db",
#     "objective": "CONVERSIONS",
#     "stop_time": "2020-11-14T12:55:00+0800",
# ...

# %%
campaign_test = Campaign('6220571440807')
print(campaign_test.get_insights(fields_insights, para_insights))

# %%
count_install = 0
count_purch = 0
count_subs = 0

for i in range(len(campaign_insights[0]['actions'])):
    if 'mobile_app_install' in campaign_insights[0]['actions'][i]['action_type']: 
        count_install = campaign_insights[0]['actions'][i]['value']
        print('mobile_app_install: ', count_install)

    elif 'purchase' in campaign_insights[0]['actions'][i]['action_type']:
        count_purch = campaign_insights[0]['actions'][i]['value']
        print('mobile_app_install: ', count_purch)

    elif 'subscription' in campaign_insights[0]['actions'][i]['action_type']: 
        count_subs = campaign_insights[0]['actions'][i]['value']
        print('mobile_app_install: ', count_subs)


print(campaign_insights[0]['actions'])

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.campaign import Campaign
from facebook_business.api import FacebookAdsApi

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# fields_campaign = 讀取的欄位清單(Column names)----------------------------------
fields_campaign = [
    'name',
    'objective',
    'id',
    'ad_set'
    'start_time',
    'stop_time', 
    'updated_time',
#     'effective_status',
]

para_campaign = {
    'time_range': {
        'since': '2020-10-30',
        'until': '2020-11-6',
    },
#     'date_preset': 'last_7d',

}

## insights API fields&para---------------------------------------------------
fields_insights = [
    'spend',
    'campaign_name',
    'conversion_values',
    'full_view_reach',
    'actions',
]

para_insights = {
    'time_range': {
        'since': '2020-10-30',
        'until': '2020-11-6',
    },
    'level': 'campaign',
#     'date_preset': 'last_7d',

}
# ---------------------------------------------------------------------------
# Count if inoder to avoid  rate limit
count = 0
# Campaign's data from the Account
A = AdAccount(ad_account_id).get_campaigns(fields_campaign, para_campaign)
for a in A:
    
    if count >= 100:
        break
    count += 1
        
    try:
        # Try to find the Campaign insights "Spend"
        campaign = Campaign(a['id'])
        campaign_insights = campaign.get_insights(fields_insights, para_insights)

        # 如果Inisghts是 None，可能是Campaign內部根本沒有inisght
        if len(campaign_insights) < 1:
            print('這是第%d個' % count)
            print(a['name'])
            print('不確定的轉換值 or 沒有設定轉換值')
            print(a, end = '\n')
            

        else:
            print('這是第%d個' % count)
            print(a['name'])

            count_install = 0
            count_purch = 0
            count_subs = 0
            
            try:
                for i in range(len(campaign_insights[0]['actions'])):
                    if campaign_insights[0]['actions'][i]['action_type'] == 'mobile_app_install': 
                        count_install = campaign_insights[0]['actions'][i]['value']
                        print('手機軟體下載數量: ', count_install)

                    elif campaign_insights[0]['actions'][i]['action_type'] == 'purchase':
                        count_purch = campaign_insights[0]['actions'][i]['value']
                        print('購買數量: ', count_purch)

                    elif campaign_insights[0]['actions'][i]['action_type'] == 'subscription': 
                        count_subs = campaign_insights[0]['actions'][i]['value']
                        print('訂閱數量: ', count_subs)
                # 將
                print(a, end = '\n')
                print(campaign_insights, end = '\n\n')
            except KeyError as e:
                print(e)
                continue

    except AttributeError as e:
        print(e)z

# %% [markdown]
# ## 20201109 利用Account直接奪取Insight API的資料(不是利用Campaign)

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights
from facebook_business.api import FacebookAdsApi
import datetime

access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


fields = [
    'spend',
    'campaign_name',
    'actions',
    'objective',
#     'purchase_roas',
#     'conversion_values',
    'action_values',   
]
params = {
    'time_range': {'since':'2020-11-01', 'until':'2020-11-08'},
    'filtering': [],
    'level': 'campaign',
    'time_increment': '1',
}

acc_insights = AdAccount(ad_account_id).get_insights(
    fields = fields,
    params = params,
)

# 抓取資料-----------------------------
count = 1
amount_install = 0
amount_purch = 0 
amount_subs = 0

for acc_insight in acc_insights:
    print('這是第%d個' % count)
    print(acc_insight['campaign_name'])
    count += 1
    # 將特定的 Action(Ex: subscribe, install, purchase)顯示 
    try:
        for action in acc_insight['actions']:
            if action['action_type'] == 'mobile_app_install': 
                amount_install = action['value']
                print('手機軟體下載數量: ', amount_install)

            elif action['action_type'] == 'purchase':
                amount_purch = action['value']
                print('購買數量: ', amount_purch)

            elif action['action_type'] == 'subscription': 
                amount_subs = action['value']
                print('訂閱數量: ', amount_subs)
        print(acc_insight, end = '\n\n')
        
    except KeyError as e:
        print('沒有Actions_insight ', e, end = '\n\n')
        continue
        
# 寫入資料庫-----------------------------------------------------
# Out:
# 這是第1個
# 期貨電子盤_下載_IOS
# 手機軟體下載數量:  1
# <AdsInsights> {
#     "actions": [
#         {
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "186"
#         },
#         {
#             "action_type": "link_click",
#             "value": "7"
#         },
#         {
#             "action_type": "mobile_app_install",
#             "value": "1"
#         },
#         {
#             "action_type": "post_reaction",
#             "value": "2"
#         },
#         {
#             "action_type": "omni_activate_app",
#             "value": "186"
#         },
#         {
#             "action_type": "post_engagement",
#             "value": "9"
#         },
#         {
#             "action_type": "page_engagement",
#             "value": "9"
#         },
#         {
#             "action_type": "omni_app_install",
#             "value": "1"
#         }
#     ],
#     "campaign_name": "\u671f\u8ca8\u96fb\u5b50\u76e4_\u4e0b\u8f09_IOS",
# ...

# %%
for i in acc_insight['actions']:
    print(i)
    print(i['action_type'] == 'mobile_app_install')
    print(i['value'])

# %% [markdown]
# ## 20201110 v1

# %%
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights
from facebook_business.api import FacebookAdsApi
import datetime
import csv

# Initialize the access_token
access_token = 'EAAJqMzKi2IsBAJp9LxmjKZBfEG5P5WXqzUO8f4eXoUYRr9beYIxSRXKFuXMUTVZCMaJnwewurtWpq93qiyB7X8wfDotZCQZC5M1B9YZAgIuiTEY5cHgOZAhmxGpOin6DM0HZAPcAmzs8YDBnAs4YzS9D1D5jZCLWLUkdhGVhbmddkAZDZD'
ad_account_id = 'act_132799196821088'
app_secret = 'b3700e4944af0e889dc572179bd6800d'
app_id = '679718078830731'

FacebookAdsApi.init(access_token = access_token)


# # Get today's date for the filename, and the csv data
# today = datetime.datetime.now() 
# todaydate = today.strftime('%m-%d-%Y')
# # todaydatehyphen = todaydate.strftime('%m-%d-%Y')

# # Define the destination filename
# # filename = todaydatehyphen + '_fb.csv'
# # filelocation = "<Your folder location>"+ filename


# # Open or create new file 
# # try:
# #     csvfile = open(filelocation , 'w')
# # except:
# #     print ("Cannot open file.")


# # To keep track of rows added to file
# # rows = 0

# # try:
# #     # Create file writer
# #     filewriter = csv.writer(csvfile, delimiter=',')
# # except Exception as err:
# #     print(err)
    

fields = [
    'spend',
    'campaign_name',
    'adset_name',
    'actions',
    'objective',
    'action_values',   
]
params = {
    'time_range': {'since':'2020-11-01', 'until':'2020-11-08'},
    'filtering': [],
    'level': {'campaign', 'adset'},
    'time_increment': '1',
}

acc_insights = AdAccount(ad_account_id).get_insights(
    fields = fields,
    params = params,
)

# 寫入資料庫-----------------------------------------------------
# 日報
# outfn = '{%Y-%m-%d}.database.csv'.format(datetime.today())

# """
outfn = '{}_fb.csv'.format('a')
title_row = ['Campaign_name', 'Adset_name', 'Amount_spent(NTD)', 'Objective', 'Amount_subscribe', 'Amount_install', 'Amount_purchase' , 'Reporting_date']

# test_count = 0
with open(outfn, 'w', newline = '') as csvout:
    csvWriter = csv.writer(csvout)
    csvWriter.writerow(title_row)

    for acc_insight in acc_insights:     
#         test_count += 1
        
        Campaign_name = ''
        Adset_name = ''
        Amount_spent = ''
        Objective = ''
        Amount_subscribe = '' 
        Amount_install = '' 
        Amount_purchase = ''    
        Reporting_date = ''

        if 'campaign_name' in acc_insight:
            Campaign_name = acc_insight['campaign_name']
        if 'adset_name' in acc_insight:
            Adset_name = acc_insight['adset_name']
        if 'spend' in acc_insight:
            Amount_spent = acc_insight['spend']
        if 'objective' in acc_insight:
            Objective = acc_insight['objective']
        if 'date_stop' in acc_insight:
            Reporting_date = acc_insight['date_stop']

        if 'actions' in acc_insight:
            for action in acc_insight['actions']:
                if action['action_type'] == 'mobile_app_install': 
                    Amount_install = action['value']

                if action['action_type'] == 'purchase':
                    Amount_purchase = action['value']

                if action['action_type'] == 'subscription': 
                    Amount_subscribe = action['value']
    
        csvWriter.writerow([
            Campaign_name,
            Adset_name,
            Amount_spent,
            Objective,
            Amount_subscribe,
            Amount_install, 
            Amount_purchase,    
            Reporting_date,
        ])
        
#         if test_count >= 10:
#             break
            
print('finish_1')
# """
# Out:
# finish_1

# %%
print(acc_insight)
print(acc_insight['Campaing'])
# Out:
# <AdsInsights> {
#     "actions": [
#         {
#             "action_type": "landing_page_view",
#             "value": "1"
#         },
#         {
#             "action_type": "app_custom_event.fb_mobile_activate_app",
#             "value": "42"
#         },
#         {
#             "action_type": "link_click",
#             "value": "25"
#         },
#         {
#             "action_type": "mobile_app_install",
#             "value": "11"
#         },
#         {
#             "action_type": "offsite_conversion.fb_pixel_add_to_cart",
#             "value": "1"
#         },
#         {
#             "action_type": "omni_activate_app",
#             "value": "42"
#         },
#         {
#             "action_type": "post_engagement",
#             "value": "25"
#         },
#         {
#             "action_type": "page_engagement",
#             "value": "25"
#         },
#         {
#             "action_type": "omni_app_install",
#             "value": "11"
#         },
# ...

# %%
'date_stop' in acc_insight
# Out:
# True
